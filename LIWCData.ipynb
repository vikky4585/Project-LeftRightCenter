# %%
import requests
import pandas as pd
from config import x_api_key,x_api_secret_key
url='https://api-v3.receptiviti.com/v3/api/content'
headers={'X-API-KEY': x_api_key, 'X-API-SECRET-KEY':x_api_secret_key}

# %%
df = pd.read_csv('compact_tweets.csv')
df = df.drop(columns=['Unnamed: 0'])
df.reset_index(drop=True)
df.head()
# Out:
#               key      party  \
# 0  RepDarrenSoto0  democrats
# 1  RepDarrenSoto1  democrats
# 2  RepDarrenSoto2  democrats
# 3  RepDarrenSoto3  democrats
# 4  RepDarrenSoto4  democrats
#
#                                                 text
# 0  And Episode 2 covers immigration just in time ...
# 1  TorresBruno family came to US legally seeking ...
# 2  SteveLemongello garywhite13 For the record in ...
# 3  On this NetNeutrality Day of Action we are bui...
# 4  Happy VeteransDay2018 and thank you to all our...

# %%
def payload(text):
    payload = {}
    tags = []
    tags.append('string')
    payload['content_tags'] = tags
    payload['content_handle'] = 'string'
    payload['language'] = 'english'
    payload['content_source'] = 4
    payload['content_date'] = '2018-12-25T00:46:05.119779'
    payload['recipient_id'] = 'string'
    payload['language_content'] = text
    return payload

# %%
raw_scores = []
percentile_scores = []
category_scores = []
liwc_scores = []

# %%
def sendLIWC(text, party, userid):
    
    print(f'sending request for userid {userid}' )

    response = requests.post(url, headers=headers,json=payload(text))
    liwc = {}
    liwc['userid'] = userid
    liwc['party'] = party
    raw_score = dict(liwc)
    raw_score.update(response.json()['receptiviti_scores']['raw_scores'])
    percentile_score = dict(liwc)
    percentile_score.update(response.json()['receptiviti_scores']['percentiles'])
    category_score = dict(liwc)
    category_score.update(response.json()['liwc_scores']['categories'])
    
    raw_scores.append(raw_score)
    percentile_scores.append(percentile_score)
    category_scores.append(category_score)
    
    #liwc_score = dict(liwc).update(response.json()['liwc_scores']['categories'])

# %%
df.apply(lambda r : sendLIWC(r['text'], r['party'],r['key']), axis=1)
#test_df = df.head()
#test_df.apply(lambda r : sendLIWC(r['text'], r['party'],r['key']), axis=1)
# Out:
# sending request for userid RepDarrenSoto0
# sending request for userid RepDarrenSoto1
# sending request for userid RepDarrenSoto2
# sending request for userid RepDarrenSoto3
# sending request for userid RepDarrenSoto4
# sending request for userid RepDarrenSoto5
# sending request for userid RepDarrenSoto6
# sending request for userid RepDarrenSoto7
# sending request for userid RepDarrenSoto8
# sending request for userid RepDarrenSoto9
# sending request for userid RepDarrenSoto10
# sending request for userid RepDarrenSoto11
# sending request for userid RepDarrenSoto12
# sending request for userid RepDarrenSoto13
# sending request for userid RepDarrenSoto14
# sending request for userid RepDarrenSoto15
# sending request for userid RepDarrenSoto16
# sending request for userid RepDarrenSoto17
# sending request for userid RepDarrenSoto18
# sending request for userid RepDarrenSoto19
# sending request for userid RepDarrenSoto20
# sending request for userid RepDarrenSoto21
# sending request for userid RepDarrenSoto22
# sending request for userid RepDarrenSoto23
# sending request for userid RepDarrenSoto24
# sending request for userid RepDarrenSoto25
# sending request for userid RepDarrenSoto26
# sending request for userid RepDarrenSoto27
# sending request for userid RepDarrenSoto28
# sending request for userid RepDarrenSoto29
# sending request for userid RepDarrenSoto30
# sending request for userid RepDarrenSoto31
# sending request for userid RepDarrenSoto32
# sending request for userid RepDarrenSoto33
# sending request for userid RepDarrenSoto34
# sending request for userid RepDarrenSoto35
# sending request for userid RepDarrenSoto36
# sending request for userid RepDarrenSoto37
# sending request for userid RepDarrenSoto38
# sending request for userid RepDarrenSoto39
# sending request for userid RepDarrenSoto40
# sending request for userid RepDarrenSoto41
# sending request for userid RepDarrenSoto42
# sending request for userid RepDarrenSoto43
# sending request for userid RepDarrenSoto44
# sending request for userid RepRoKhanna0
# sending request for userid RepRoKhanna1
# sending request for userid RepRoKhanna2
# sending request for userid RepRoKhanna3
# sending request for userid RepRoKhanna4
# sending request for userid RepRoKhanna5
# sending request for userid RepRoKhanna6
# sending request for userid RepRoKhanna7
# sending request for userid RepRoKhanna8
# sending request for userid RepRoKhanna9
# sending request for userid RepRoKhanna10
# sending request for userid RepRoKhanna11
# sending request for userid RepRoKhanna12
# sending request for userid RepRoKhanna13
# sending request for userid RepRoKhanna14
# sending request for userid RepRoKhanna15
# sending request for userid RepRoKhanna16
# sending request for userid RepRoKhanna17
# sending request for userid RepRoKhanna18
# sending request for userid RepRoKhanna19
# sending request for userid RepRoKhanna20
# sending request for userid RepRoKhanna21
# sending request for userid CongressmanRaja0
# sending request for userid CongressmanRaja1
# sending request for userid CongressmanRaja2
# sending request for userid CongressmanRaja3
# sending request for userid CongressmanRaja4
# sending request for userid CongressmanRaja5
# sending request for userid CongressmanRaja6
# sending request for userid CongressmanRaja7
# sending request for userid CongressmanRaja8
# sending request for userid CongressmanRaja9
# sending request for userid CongressmanRaja10
# sending request for userid CongressmanRaja11
# sending request for userid CongressmanRaja12
# sending request for userid CongressmanRaja13
# sending request for userid CongressmanRaja14
# sending request for userid CongressmanRaja15
# sending request for userid CongressmanRaja16
# sending request for userid CongressmanRaja17
# sending request for userid CongressmanRaja18
# sending request for userid CongressmanRaja19
# sending request for userid CongressmanRaja20
# sending request for userid CongressmanRaja21
# sending request for userid RepTedLieu0
# sending request for userid RepTedLieu1
# sending request for userid RepTedLieu2
# sending request for userid RepTedLieu3
# sending request for userid RepTedLieu4
# sending request for userid RepTedLieu5
# sending request for userid RepTedLieu6
# sending request for userid RepTedLieu7
# sending request for userid RepTedLieu8
# sending request for userid RepTedLieu9
# sending request for userid RepTedLieu10
# sending request for userid RepTedLieu11
# sending request for userid RepTedLieu12
# sending request for userid RepTedLieu13
# sending request for userid RepTedLieu14
# sending request for userid RepTedLieu15
# sending request for userid RepTedLieu16
# sending request for userid RepTedLieu17
# sending request for userid RepTedLieu18
# sending request for userid RepTedLieu19
# sending request for userid RepTedLieu20
# sending request for userid RepTedLieu21
# sending request for userid RepStephMurphy0
# sending request for userid RepStephMurphy1
# sending request for userid RepStephMurphy2
# sending request for userid RepStephMurphy3
# sending request for userid RepStephMurphy4
# sending request for userid RepStephMurphy5
# sending request for userid RepStephMurphy6
# sending request for userid RepStephMurphy7
# sending request for userid RepStephMurphy8
# sending request for userid RepStephMurphy9
# sending request for userid RepStephMurphy10
# sending request for userid RepStephMurphy11
# sending request for userid RepStephMurphy12
# sending request for userid RepStephMurphy13
# sending request for userid RepStephMurphy14
# sending request for userid RepStephMurphy15
# sending request for userid RepStephMurphy16
# sending request for userid RepStephMurphy17
# sending request for userid RepStephMurphy18
# sending request for userid RepStephMurphy19
# sending request for userid RepStephMurphy20
# sending request for userid RepStephMurphy21
# sending request for userid RepDonBeyer0
# sending request for userid RepDonBeyer1
# sending request for userid RepDonBeyer2
# sending request for userid RepDonBeyer3
# sending request for userid RepDonBeyer4
# sending request for userid RepDonBeyer5
# sending request for userid RepDonBeyer6
# sending request for userid RepDonBeyer7
# sending request for userid RepDonBeyer8
# sending request for userid RepDonBeyer9
# sending request for userid RepDonBeyer10
# sending request for userid RepDonBeyer11
# sending request for userid RepDonBeyer12
# sending request for userid RepDonBeyer13
# sending request for userid RepDonBeyer14
# sending request for userid RepDonBeyer15
# sending request for userid RepDonBeyer16
# sending request for userid RepDonBeyer17
# sending request for userid RepDonBeyer18
# sending request for userid RepDonBeyer19
# sending request for userid RepDonBeyer20
# sending request for userid RepDonBeyer21
# sending request for userid RepSinema0
# sending request for userid RepSinema1
# sending request for userid RepSinema2
# sending request for userid RepSinema3
# sending request for userid RepSinema4
# sending request for userid RepSinema5
# sending request for userid RepSinema6
# sending request for userid RepSinema7
# sending request for userid RepSinema8
# sending request for userid RepSinema9
# sending request for userid RepSinema10
# sending request for userid RepSinema11
# sending request for userid RepSinema12
# sending request for userid RepSinema13
# sending request for userid RepSinema14
# sending request for userid RepSinema15
# sending request for userid RepSinema16
# sending request for userid RepSinema17
# sending request for userid RepSinema18
# sending request for userid RepSinema19
# sending request for userid RepSinema20
# sending request for userid RepSinema21
# sending request for userid RepComstock0
# sending request for userid RepComstock1
# sending request for userid RepComstock2
# sending request for userid RepComstock3
# sending request for userid RepComstock4
# sending request for userid RepComstock5
# sending request for userid RepComstock6
# sending request for userid RepComstock7
# sending request for userid RepComstock8
# sending request for userid RepComstock9
# sending request for userid RepComstock10
# sending request for userid RepComstock11
# sending request for userid RepComstock12
# sending request for userid RepComstock13
# sending request for userid RepComstock14
# sending request for userid RepComstock15
# sending request for userid RepComstock16
# sending request for userid RepComstock17
# sending request for userid RepComstock18
# sending request for userid RepComstock19
# sending request for userid RepComstock20
# sending request for userid RepComstock21
# sending request for userid RepJasonSmith0
# sending request for userid RepJasonSmith1
# sending request for userid RepJasonSmith2
# sending request for userid RepJasonSmith3
# sending request for userid RepJasonSmith4
# sending request for userid RepJasonSmith5
# sending request for userid RepJasonSmith6
# sending request for userid RepJasonSmith7
# sending request for userid RepJasonSmith8
# sending request for userid RepJasonSmith9
# sending request for userid RepJasonSmith10
# sending request for userid RepJasonSmith11
# sending request for userid RepJasonSmith12
# sending request for userid RepJasonSmith13
# sending request for userid RepJasonSmith14
# sending request for userid RepJasonSmith15
# sending request for userid RepJasonSmith16
# sending request for userid RepJasonSmith17
# sending request for userid RepJasonSmith18
# sending request for userid RepJasonSmith19
# sending request for userid RepJasonSmith20
# sending request for userid RepJasonSmith21
# sending request for userid Rep_Hunter0
# sending request for userid Rep_Hunter1
# sending request for userid Rep_Hunter2
# sending request for userid Rep_Hunter3
# sending request for userid Rep_Hunter4
# sending request for userid Rep_Hunter5
# sending request for userid Rep_Hunter6
# sending request for userid Rep_Hunter7
# sending request for userid Rep_Hunter8
# sending request for userid Rep_Hunter9
# sending request for userid Rep_Hunter10
# sending request for userid Rep_Hunter11
# sending request for userid Rep_Hunter12
# sending request for userid Rep_Hunter13
# sending request for userid Rep_Hunter14
# sending request for userid Rep_Hunter15
# sending request for userid Rep_Hunter16
# sending request for userid Rep_Hunter17
# sending request for userid Rep_Hunter18
# sending request for userid Rep_Hunter19
# sending request for userid Rep_Hunter20
# sending request for userid Rep_Hunter21
# sending request for userid SusanWBrooks0
# sending request for userid SusanWBrooks1
# sending request for userid SusanWBrooks2
# sending request for userid SusanWBrooks3
# sending request for userid SusanWBrooks4
# sending request for userid SusanWBrooks5
# sending request for userid SusanWBrooks6
# sending request for userid SusanWBrooks7
# sending request for userid SusanWBrooks8
# sending request for userid SusanWBrooks9
# sending request for userid SusanWBrooks10
# sending request for userid SusanWBrooks11
# sending request for userid SusanWBrooks12
# sending request for userid SusanWBrooks13
# sending request for userid SusanWBrooks14
# sending request for userid SusanWBrooks15
# sending request for userid SusanWBrooks16
# sending request for userid SusanWBrooks17
# sending request for userid SusanWBrooks18
# sending request for userid SusanWBrooks19
# sending request for userid SusanWBrooks20
# sending request for userid SusanWBrooks21
# sending request for userid RepRichHudson0
# sending request for userid RepRichHudson1
# sending request for userid RepRichHudson2
# sending request for userid RepRichHudson3
# sending request for userid RepRichHudson4
# sending request for userid RepRichHudson5
# sending request for userid RepRichHudson6
# sending request for userid RepRichHudson7
# sending request for userid RepRichHudson8
# sending request for userid RepRichHudson9
# sending request for userid RepRichHudson10
# sending request for userid RepRichHudson11
# sending request for userid RepRichHudson12
# sending request for userid RepRichHudson13
# sending request for userid RepRichHudson14
# sending request for userid RepRichHudson15
# sending request for userid RepRichHudson16
# sending request for userid RepRichHudson17
# sending request for userid RepRichHudson18
# sending request for userid RepRichHudson19
# sending request for userid RepRichHudson20
# sending request for userid RepRichHudson21
# sending request for userid RepChuck0
# sending request for userid RepChuck1
# sending request for userid RepChuck2
# sending request for userid RepChuck3
# sending request for userid RepChuck4
# sending request for userid RepChuck5
# sending request for userid RepChuck6
# sending request for userid RepChuck7
# sending request for userid RepChuck8
# sending request for userid RepChuck9
# sending request for userid RepChuck10
# sending request for userid RepChuck11
# sending request for userid RepChuck12
# sending request for userid RepChuck13
# sending request for userid RepChuck14
# sending request for userid RepChuck15
# sending request for userid RepChuck16
# sending request for userid RepChuck17
# sending request for userid RepChuck18
# sending request for userid RepChuck19
# sending request for userid RepChuck20
# sending request for userid RepChuck21
# sending request for userid RepKenMarchant0
# sending request for userid RepKenMarchant1
# sending request for userid RepKenMarchant2
# sending request for userid RepKenMarchant3
# sending request for userid RepKenMarchant4
# sending request for userid RepKenMarchant5
# sending request for userid RepKenMarchant6
# sending request for userid RepKenMarchant7
# sending request for userid RepKenMarchant8
# sending request for userid RepKenMarchant9
# sending request for userid RepKenMarchant10
# sending request for userid RepKenMarchant11
# sending request for userid RepKenMarchant12
# sending request for userid RepKenMarchant13
# sending request for userid RepKenMarchant14
# sending request for userid RepKenMarchant15
# sending request for userid RepKenMarchant16
# sending request for userid RepKenMarchant17
# sending request for userid RepKenMarchant18
# sending request for userid RepKenMarchant19
# sending request for userid RepKenMarchant20
# sending request for userid RepKenMarchant21
# sending request for userid GOPLeader0
# sending request for userid GOPLeader1
# sending request for userid GOPLeader2
# sending request for userid GOPLeader3
# sending request for userid GOPLeader4
# sending request for userid GOPLeader5
# sending request for userid GOPLeader6
# sending request for userid GOPLeader7
# sending request for userid GOPLeader8
# sending request for userid GOPLeader9
# sending request for userid GOPLeader10
# sending request for userid GOPLeader11
# sending request for userid GOPLeader12
# sending request for userid GOPLeader13
# sending request for userid GOPLeader14
# sending request for userid GOPLeader15
# sending request for userid GOPLeader16
# sending request for userid GOPLeader17
# sending request for userid GOPLeader18
# sending request for userid GOPLeader19
# sending request for userid GOPLeader20
# sending request for userid GOPLeader21
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 323    None
# 324    None
# 325    None
# 326    None
# 327    None
# 328    None
# 329    None
# 330    None
# 331    None
# 332    None
# 333    None
# 334    None
# 335    None
# 336    None
# 337    None
# 338    None
# 339    None
# 340    None
# 341    None
# 342    None
# 343    None
# 344    None
# 345    None
# 346    None
# 347    None
# 348    None
# 349    None
# 350    None
# 351    None
# 352    None
# Length: 353, dtype: object

# %%
print(len(raw_scores))
raw_scores
# Out:
# 353
# [{'userid': 'RepDarrenSoto0',
#   'party': 'democrats',
#   'imaginative': -1.3294975176377377,
#   'netspeak_focus': 0.67114094,
#   'persuasive': 2.477204408982728,
#   'liberal': 0.6746592603371968,
#   'self_assured': 0.11808287143690777,
#   'body_focus': 0.22371365,
#   'trusting': -1.1180556909705646,
#   'organized': 2.0970023042853363,
#   'type_a': 9.82341571276347,
#   'intellectual': 7.6273639056602835,
#   'cheerful': -0.5212886109370327,
#   'disciplined': 3.270093350293563,
#   'neuroticism': 1.901244880237649,
#   'cooperative': 3.5761872581935683,
#   'social_skills': 1.625934610494727,
#   'openness': 0.5921073102334817,
#   'aggressive': 2.8489543483077457,
#   'adjustment': 2.9972408830553467,
#   'religion_oriented': 0.22371365,
#   'empathetic': -3.0513202993047055,
#   'food_focus': 0.0,
#   'generous': -3.8810167668131967,
#   'sexual_focus': 0.22371365,
#   'thinking_style': 1.6727409140267926,
#   'friend_focus': 0.4474273,
#   'extraversion': 0.3985749378348697,
#   'agreeableness': -7.310596448132699,
#   'depression': 2.7578317164677117,
#   'ambitious': 3.6710265093792946,
#   'friendly': 1.0265861218394692,
#   'money_oriented': 1.3422819000000001,
#   'independent': -2.339235952857969,
#   'melancholy': 3.2848426711304577,
#   'workhorse': -1.1113216932170389,
#   'reward_bias': 0.0,
#   'energetic': -0.1648423407867594,
#   'happiness': 3.0401079966448608,
#   'self_conscious': 3.388165002010315,
#   'assertive': 3.067256766476622,
#   'insecure': -0.22567299473814773,
#   'leisure_oriented': 1.1185682000000001,
#   'impulsive': -0.6991521563186407,
#   'cautious': 5.954156081123668,
#   'conscientiousness': 1.9937265411192664,
#   'active': -2.227964643992822,
#   'power_driven': 6.813811903800079,
#   'dutiful': 1.7123731675593898,
#   'genuine': -2.1292585584771544,
#   'adventurous': 1.3694103344972346,
#   'sociable': 3.4223229870973326,
#   'family_oriented': 2.7109112256441046,
#   'cold': -3.1827476634660368,
#   'emotionally_aware': -1.3980206563303905,
#   'humble': -2.6768999279808354,
#   'anxious': 7.038910918616178,
#   'artistic': 3.8887766452064634,
#   'stressed': 11.006219957837855,
#   'health_oriented': 0.0,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto1',
#   'party': 'democrats',
#   'imaginative': -1.3931686073283602,
#   'netspeak_focus': 0.44052859999999994,
#   'persuasive': 1.847803900866598,
#   'liberal': -0.8974073675974716,
#   'self_assured': 0.1533462862142092,
#   'body_focus': 0.22026429999999997,
#   'trusting': -1.2110834116127347,
#   'organized': 1.3987375587386115,
#   'type_a': 9.22663017565184,
#   'intellectual': 7.724187253108584,
#   'cheerful': 0.22705332700098402,
#   'disciplined': 2.8580977681910453,
#   'neuroticism': 1.864608223223061,
#   'cooperative': 4.132322272641515,
#   'social_skills': 1.4894132825828015,
#   'openness': 0.22458608314738582,
#   'aggressive': 2.3365417079447894,
#   'adjustment': 3.5679782074743205,
#   'religion_oriented': 0.0,
#   'empathetic': -2.8807031086807315,
#   'food_focus': 0.22026429999999997,
#   'generous': -3.495037494615631,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.4181432231940363,
#   'friend_focus': 0.44052859999999994,
#   'extraversion': 0.3814370073781501,
#   'agreeableness': -6.654001110694398,
#   'depression': 1.266182414006191,
#   'ambitious': 4.081533634453385,
#   'friendly': 1.4649311548961124,
#   'money_oriented': 1.54185025,
#   'independent': -1.305018726544291,
#   'melancholy': 2.672892355763535,
#   'workhorse': 0.8446191256978788,
#   'reward_bias': 0.44052853000000003,
#   'energetic': -0.6594708103426288,
#   'happiness': 3.603593471890897,
#   'self_conscious': 3.5566301723935676,
#   'assertive': 2.8003457798886817,
#   'insecure': -0.21504956805716513,
#   'leisure_oriented': 1.54185025,
#   'impulsive': 0.5478507292475947,
#   'cautious': 3.9877621406952355,
#   'conscientiousness': 1.7567070487205263,
#   'active': -2.429212200816091,
#   'power_driven': 7.658370374944449,
#   'dutiful': 2.2270234191633853,
#   'genuine': -1.9620016875432968,
#   'adventurous': 0.7653552384860655,
#   'sociable': 3.3038667171512053,
#   'family_oriented': 3.404668139901951,
#   'cold': -3.445389683289187,
#   'emotionally_aware': -0.811998171160926,
#   'humble': -2.4110967399444054,
#   'anxious': 6.683320680182608,
#   'artistic': 3.325704363913824,
#   'stressed': 10.216461181217344,
#   'health_oriented': 1.1013215,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto2',
#   'party': 'democrats',
#   'imaginative': -1.9615390944609816,
#   'netspeak_focus': 0.0,
#   'persuasive': 3.4139492064625325,
#   'liberal': -1.0491598103266595,
#   'self_assured': 0.1537458361877304,
#   'body_focus': 0.0,
#   'trusting': 0.5193625824817607,
#   'organized': 2.0752087427182544,
#   'type_a': 10.507065761520684,
#   'intellectual': 9.001117911331567,
#   'cheerful': 0.29323868285003707,
#   'disciplined': 4.4650129876710976,
#   'neuroticism': 1.317471003947738,
#   'cooperative': 6.158282719954723,
#   'social_skills': 1.4093334346499797,
#   'openness': -0.25494559872474676,
#   'aggressive': 1.494638403924528,
#   'adjustment': 6.448708159261985,
#   'religion_oriented': 0.0,
#   'empathetic': -3.100371668079138,
#   'food_focus': 0.0,
#   'generous': -3.9436615020308317,
#   'sexual_focus': 0.0,
#   'thinking_style': 3.1761878151374114,
#   'friend_focus': 0.0,
#   'extraversion': 1.2067261076431381,
#   'agreeableness': -6.247666827707754,
#   'depression': -0.17802480462986425,
#   'ambitious': 6.077654560580333,
#   'friendly': 2.436309237456058,
#   'money_oriented': 1.4778325,
#   'independent': -1.4421802134201647,
#   'melancholy': 1.0898934406616514,
#   'workhorse': 1.1298842399869442,
#   'reward_bias': 0.4926108000000001,
#   'energetic': -0.418386546466462,
#   'happiness': 3.9478704537075533,
#   'self_conscious': 2.648079412825651,
#   'assertive': 2.7340651899009507,
#   'insecure': -1.7787317793865565,
#   'leisure_oriented': 1.23152705,
#   'impulsive': -0.06490997680033228,
#   'cautious': 5.059705336379983,
#   'conscientiousness': 2.60503549662443,
#   'active': 0.10008774851132402,
#   'power_driven': 9.639484368182202,
#   'dutiful': 3.654050530021069,
#   'genuine': -0.978237018350351,
#   'adventurous': 0.8338549467855455,
#   'sociable': 5.2231358562663885,
#   'family_oriented': 2.7094346758461967,
#   'cold': -3.3878173177914173,
#   'emotionally_aware': -2.263722615475964,
#   'humble': -3.292147620468116,
#   'anxious': 4.192174159147319,
#   'artistic': 2.0932754279533214,
#   'stressed': 10.874590513695418,
#   'health_oriented': 0.0,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto3',
#   'party': 'democrats',
#   'imaginative': -1.2477797851314107,
#   'netspeak_focus': 0.0,
#   'persuasive': 2.0923927747488893,
#   'liberal': -1.615940711801897,
#   'self_assured': 0.5145026266482287,
#   'body_focus': 0.0,
#   'trusting': -0.35846501475878334,
#   'organized': 2.0771498489792424,
#   'type_a': 11.05002064038277,
#   'intellectual': 7.771608668116395,
#   'cheerful': -0.9264975995713498,
#   'disciplined': 4.338843156590942,
#   'neuroticism': 1.5441815768761584,
#   'cooperative': 4.554560807806667,
#   'social_skills': 1.2821292990707382,
#   'openness': 0.12032704477116145,
#   'aggressive': 4.013585690528183,
#   'adjustment': 3.471527196125714,
#   'religion_oriented': 0.0,
#   'empathetic': -3.391260757542299,
#   'food_focus': 0.6423983,
#   'generous': -4.687047567982065,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.8006269675755355,
#   'friend_focus': 0.42826549999999997,
#   'extraversion': 0.3062628934336101,
#   'agreeableness': -8.324289234162375,
#   'depression': 2.243377024617024,
#   'ambitious': 6.623179425738165,
#   'friendly': 1.0147529171686331,
#   'money_oriented': 1.7130619999999999,
#   'independent': -0.2099777014925519,
#   'melancholy': 0.5197382070700213,
#   'workhorse': 0.4960194823115015,
#   'reward_bias': 0.4282655000000002,
#   'energetic': -1.4384688356546653,
#   'happiness': 5.96939383457865,
#   'self_conscious': 3.9183557973665666,
#   'assertive': 3.229380733500162,
#   'insecure': -0.30519960210567865,
#   'leisure_oriented': 0.21413276,
#   'impulsive': -0.24390370523631688,
#   'cautious': 5.849957853992866,
#   'conscientiousness': 2.5738683515356415,
#   'active': -2.0548919771008003,
#   'power_driven': 7.772633088593788,
#   'dutiful': 2.705517882012976,
#   'genuine': -2.2159063685882954,
#   'adventurous': 1.3438138464343943,
#   'sociable': 4.143939378070162,
#   'family_oriented': 3.951603822191104,
#   'cold': -3.1919205322962174,
#   'emotionally_aware': -1.1236406989562604,
#   'humble': -3.439724866909585,
#   'anxious': 5.607089484754103,
#   'artistic': 2.174389407001795,
#   'stressed': 9.562357039828774,
#   'health_oriented': 0.21413276,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto4',
#   'party': 'democrats',
#   'imaginative': -0.7948389007253983,
#   'netspeak_focus': 0.39138943,
#   'persuasive': 2.1581490721495205,
#   'liberal': -1.2734540441833508,
#   'self_assured': 0.2988726164217308,
#   'body_focus': 0.19569471000000002,
#   'trusting': 0.6984392607255434,
#   'organized': 2.864531201659259,
#   'type_a': 10.07576157167185,
#   'intellectual': 7.493219379225834,
#   'cheerful': 0.026713388560101192,
#   'disciplined': 2.938573682052398,
#   'neuroticism': 1.913185307847097,
#   'cooperative': 4.993652145811517,
#   'social_skills': 1.8369578322707425,
#   'openness': 0.3940354700536482,
#   'aggressive': 3.672173828728205,
#   'adjustment': 4.428112892469306,
#   'religion_oriented': 0.0,
#   'empathetic': -2.310483542060816,
#   'food_focus': 0.19569471000000002,
#   'generous': -2.9557975718775182,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.5772700537873887,
#   'friend_focus': 0.39138943,
#   'extraversion': 0.39577651132509034,
#   'agreeableness': -4.958426356948893,
#   'depression': 2.882994594802926,
#   'ambitious': 3.274919342228505,
#   'friendly': 1.3495974808627667,
#   'money_oriented': 2.1526419000000003,
#   'independent': -1.0662922414122338,
#   'melancholy': 3.3422601732916206,
#   'workhorse': -0.4882691697332754,
#   'reward_bias': -0.3913894,
#   'energetic': -2.0474844144872733,
#   'happiness': 3.605853644735596,
#   'self_conscious': 2.425738352363263,
#   'assertive': 3.556027253038132,
#   'insecure': 0.13529741414113183,
#   'leisure_oriented': 0.58708414,
#   'impulsive': -0.35386330033842484,
#   'cautious': 5.413439535211268,
#   'conscientiousness': 2.1275402224438844,
#   'active': -2.476692249499374,
#   'power_driven': 7.386375121832039,
#   'dutiful': 2.0879471540891084,
#   'genuine': -1.2060878912758652,
#   'adventurous': 1.1577372024326877,
#   'sociable': 4.566269894428769,
#   'family_oriented': 3.272498771110221,
#   'cold': -2.6618894296075566,
#   'emotionally_aware': -1.3074134171171141,
#   'humble': -2.2818644864016893,
#   'anxious': 6.056548323289966,
#   'artistic': 3.047233763741023,
#   'stressed': 12.496129423500708,
#   'health_oriented': 0.39138943,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto5',
#   'party': 'democrats',
#   'imaginative': -1.5717128841847159,
#   'netspeak_focus': 0.0,
#   'persuasive': 2.5040226498696185,
#   'liberal': 1.1095085639620654,
#   'self_assured': 0.4802681095321457,
#   'body_focus': 0.6355932,
#   'trusting': 0.0025714808047343496,
#   'organized': 1.3560176721794028,
#   'type_a': 11.403248806649025,
#   'intellectual': 9.753149275437526,
#   'cheerful': -0.8514074257615032,
#   'disciplined': 3.71321387202818,
#   'neuroticism': 1.8805311237878453,
#   'cooperative': 4.629954030333619,
#   'social_skills': 0.9992006744327874,
#   'openness': 0.46184860245369047,
#   'aggressive': 3.1779341865572457,
#   'adjustment': 1.345024796885812,
#   'religion_oriented': 0.42372879999999996,
#   'empathetic': -2.7846915587717467,
#   'food_focus': 0.42372879999999996,
#   'generous': -3.044109129491076,
#   'sexual_focus': 0.21186439999999998,
#   'thinking_style': 1.5141403594536509,
#   'friend_focus': 0.42372879999999996,
#   'extraversion': 0.5423856225936561,
#   'agreeableness': -4.45498043221282,
#   'depression': 2.635457471442799,
#   'ambitious': 5.6030365637371276,
#   'friendly': 1.3124331522098585,
#   'money_oriented': 0.21186439999999998,
#   'independent': -4.450738826500916,
#   'melancholy': 3.700717570449548,
#   'workhorse': 0.47609580996667256,
#   'reward_bias': 0.42372889999999996,
#   'energetic': 0.6518484368193622,
#   'happiness': 3.8002579948947792,
#   'self_conscious': 2.6698311823647294,
#   'assertive': 1.4128249880310817,
#   'insecure': -0.3558130424365471,
#   'leisure_oriented': 0.8474575999999999,
#   'impulsive': 0.6559739921473198,
#   'cautious': 3.4506533937668564,
#   'conscientiousness': 1.9336586869586585,
#   'active': -1.9019121543608795,
#   'power_driven': 9.655556746767266,
#   'dutiful': 2.168948764533424,
#   'genuine': -0.14294034998945815,
#   'adventurous': 1.1328541054676429,
#   'sociable': 5.920806053521585,
#   'family_oriented': 3.2592485196753356,
#   'cold': -1.8523678970065958,
#   'emotionally_aware': -1.7082667574605566,
#   'humble': -2.0724148242272915,
#   'anxious': 5.800683455832284,
#   'artistic': 2.993982538599641,
#   'stressed': 9.368433510555814,
#   'health_oriented': 1.0593221,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto6',
#   'party': 'democrats',
#   'imaginative': -1.5312503352207338,
#   'netspeak_focus': 0.0,
#   'persuasive': 3.9030456208732094,
#   'liberal': -0.7808664140885144,
#   'self_assured': 0.29372111086691044,
#   'body_focus': 0.0,
#   'trusting': 0.4039951065733467,
#   'organized': 1.931787141440049,
#   'type_a': 11.202481580199466,
#   'intellectual': 9.115778745508948,
#   'cheerful': -0.14947406636826988,
#   'disciplined': 3.829153837113825,
#   'neuroticism': 1.010788674152578,
#   'cooperative': 5.490408466939645,
#   'social_skills': 1.5743567855338771,
#   'openness': -0.017223908871542876,
#   'aggressive': 2.53548088150964,
#   'adjustment': 4.856086296699696,
#   'religion_oriented': 0.25575447,
#   'empathetic': -2.8377900884485694,
#   'food_focus': 0.0,
#   'generous': -3.6342086431618252,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.6369606028000594,
#   'friend_focus': 0.0,
#   'extraversion': 1.1210663110078527,
#   'agreeableness': -5.346500711278502,
#   'depression': -0.5088854339332699,
#   'ambitious': 7.344114574596342,
#   'friendly': 2.176012433563006,
#   'money_oriented': 0.5115089500000001,
#   'independent': -2.155023470669583,
#   'melancholy': -1.2558964795344152,
#   'workhorse': 1.8642912242882346,
#   'reward_bias': 0.5115089500000001,
#   'energetic': 0.9793220237712328,
#   'happiness': 5.158576698307929,
#   'self_conscious': 2.551253400801603,
#   'assertive': 1.4380685077735884,
#   'insecure': -0.30585906148132125,
#   'leisure_oriented': 0.5115089500000001,
#   'impulsive': 1.3743220122695763,
#   'cautious': 2.5368514002097697,
#   'conscientiousness': 2.2298022229585897,
#   'active': -0.21530170266358228,
#   'power_driven': 8.750370297920245,
#   'dutiful': 2.900761450941293,
#   'genuine': -0.5150562874875757,
#   'adventurous': 0.9917281460911669,
#   'sociable': 6.057880526200991,
#   'family_oriented': 2.526416470668804,
#   'cold': -1.9489887764369065,
#   'emotionally_aware': -1.4887745134101091,
#   'humble': -2.4675872015197506,
#   'anxious': 4.106932659295261,
#   'artistic': 1.4560097395691205,
#   'stressed': 7.033770812843701,
#   'health_oriented': 1.0230179000000001,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto7',
#   'party': 'democrats',
#   'imaginative': -0.8382420523757788,
#   'netspeak_focus': 0.24875621,
#   'persuasive': 1.3893315953365755,
#   'liberal': -0.09893909378292953,
#   'self_assured': -0.05591185808606802,
#   'body_focus': 0.0,
#   'trusting': 0.20782826205647886,
#   'organized': 1.9920195307095256,
#   'type_a': 11.931570271576678,
#   'intellectual': 8.131583015243448,
#   'cheerful': -0.10296158203981598,
#   'disciplined': 3.0566479146528414,
#   'neuroticism': 1.6299495776054713,
#   'cooperative': 4.125397530100097,
#   'social_skills': 1.304901736654768,
#   'openness': 0.6680605097179011,
#   'aggressive': 4.599899171087795,
#   'adjustment': 3.0449699592319766,
#   'religion_oriented': 0.0,
#   'empathetic': -2.21580160484617,
#   'food_focus': 0.24875621,
#   'generous': -2.7324661746495424,
#   'sexual_focus': 0.24875621,
#   'thinking_style': 2.0254884836467464,
#   'friend_focus': 0.24875621,
#   'extraversion': 0.992736502531616,
#   'agreeableness': -5.084959872805726,
#   'depression': 1.834371992251555,
#   'ambitious': 4.180834083122658,
#   'friendly': 1.507578984097282,
#   'money_oriented': 1.9900497,
#   'independent': -1.2763118643391964,
#   'melancholy': 0.9424871528921335,
#   'workhorse': -2.7618326109123856,
#   'reward_bias': -0.7462685999999998,
#   'energetic': 0.8369100433871308,
#   'happiness': 3.645695759131856,
#   'self_conscious': 2.7758465444058853,
#   'assertive': 3.0683990507723253,
#   'insecure': -0.197852925866981,
#   'leisure_oriented': 0.24875621,
#   'impulsive': 0.17647016790012193,
#   'cautious': 5.175180429577464,
#   'conscientiousness': 2.0055757409038213,
#   'active': -1.135775243012373,
#   'power_driven': 5.293044036603623,
#   'dutiful': 2.2848859405027433,
#   'genuine': -1.4817034212034277,
#   'adventurous': 1.6324847022378366,
#   'sociable': 4.803300097544817,
#   'family_oriented': 2.497792363786775,
#   'cold': -1.877195707169543,
#   'emotionally_aware': -0.3621062032468903,
#   'humble': -2.5739531535042093,
#   'anxious': 4.421561658863369,
#   'artistic': 2.3976280421566427,
#   'stressed': 12.342619308188379,
#   'health_oriented': 0.0,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto8',
#   'party': 'democrats',
#   'imaginative': -1.906871486664792,
#   'netspeak_focus': 0.0,
#   'persuasive': 2.0064272323684853,
#   'liberal': -0.2075070000000001,
#   'self_assured': 1.2389406358768404,
#   'body_focus': 0.0,
#   'trusting': -1.293568175053327,
#   'organized': 2.382164206278027,
#   'type_a': 9.672066543629633,
#   'intellectual': 9.18915762095961,
#   'cheerful': -0.4042164741905969,
#   'disciplined': 5.287880167203518,
#   'neuroticism': 1.1936286828967115,
#   'cooperative': 4.416126181900707,
#   'social_skills': 1.6795035500413746,
#   'openness': 0.06744424352729121,
#   'aggressive': 0.6225832421847322,
#   'adjustment': 4.446828320176949,
#   'religion_oriented': 0.0,
#   'empathetic': -3.0421067085434634,
#   'food_focus': 0.9732360000000001,
#   'generous': -4.386477430367108,
#   'sexual_focus': 0.0,
#   'thinking_style': 3.532540896779383,
#   'friend_focus': 0.0,
#   'extraversion': 0.3912424781998026,
#   'agreeableness': -7.936291705755664,
#   'depression': 0.49399332046316013,
#   'ambitious': 8.959987989949749,
#   'friendly': 1.7959012648719663,
#   'money_oriented': 1.459854,
#   'independent': 1.2602781530153415,
#   'melancholy': 0.058747831613119805,
#   'workhorse': 3.070720046898898,
#   'reward_bias': 0.973236,
#   'energetic': -0.7284665453041463,
#   'happiness': 5.436957334590796,
#   'self_conscious': 3.2801172415326327,
#   'assertive': 2.6919635086231892,
#   'insecure': -1.451751345384797,
#   'leisure_oriented': 0.24330900000000003,
#   'impulsive': 1.0365271047039795,
#   'cautious': 4.233628814755383,
#   'conscientiousness': 2.989329595524805,
#   'active': -2.4673256948741855,
#   'power_driven': 10.306284150667807,
#   'dutiful': 3.3937736604687534,
#   'genuine': -2.181470635673624,
#   'adventurous': 1.092731824874861,
#   'sociable': 4.254277319070319,
#   'family_oriented': 1.3573317699562764,
#   'cold': -3.194125,
#   'emotionally_aware': -0.9341869185128866,
#   'humble': -3.180628179267649,
#   'anxious': 5.454692217224669,
#   'artistic': 2.04956163016158,
#   'stressed': 7.2142005532253,
#   'health_oriented': 1.459854,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto9',
#   'party': 'democrats',
#   'imaginative': -1.5671130693329873,
#   'netspeak_focus': 0.0,
#   'persuasive': 3.6807567101842444,
#   'liberal': -0.7019388257534245,
#   'self_assured': 1.7251276263466568,
#   'body_focus': 0.4514673,
#   'trusting': 1.1623138826942827,
#   'organized': 2.684145932884235,
#   'type_a': 9.865919679069762,
#   'intellectual': 8.666131093939914,
#   'cheerful': -0.7592868952244305,
#   'disciplined': 3.3573279502810065,
#   'neuroticism': 1.8007396595178327,
#   'cooperative': 4.684128449228546,
#   'social_skills': 2.1663236292656456,
#   'openness': 0.1366860415151389,
#   'aggressive': 1.7772611551837527,
#   'adjustment': 4.449459153536771,
#   'religion_oriented': 0.4514673,
#   'empathetic': -2.9342475851511445,
#   'food_focus': 0.22573364,
#   'generous': -3.9356573083683255,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.7295948870419102,
#   'friend_focus': 0.0,
#   'extraversion': -0.2561880450525197,
#   'agreeableness': -6.012969327619799,
#   'depression': 3.86488864336488,
#   'ambitious': 6.043034884016615,
#   'friendly': 1.0527086466141022,
#   'money_oriented': 0.9029346,
#   'independent': -2.9257730326215547,
#   'melancholy': 4.566102579818741,
#   'workhorse': 2.5979379207437163,
#   'reward_bias': -0.22573369999999993,
#   'energetic': -3.1135557332970025,
#   'happiness': 2.7434174515735057,
#   'self_conscious': 2.5904744088176352,
#   'assertive': 2.4699134835978147,
#   'insecure': -1.0523061950312234,
#   'leisure_oriented': 1.3544018,
#   'impulsive': 0.01685835818298065,
#   'cautious': 5.4769020422535215,
#   'conscientiousness': 2.6696232891729643,
#   'active': -3.4006122816229984,
#   'power_driven': 9.82073058130136,
#   'dutiful': 2.6795564788755697,
#   'genuine': -0.8741816130161741,
#   'adventurous': 1.087242826098252,
#   'sociable': 4.398564063712104,
#   'family_oriented': 3.7072708353601405,
#   'cold': -4.27458082073178,
#   'emotionally_aware': -1.5055796141285867,
#   'humble': -2.967246507993705,
#   'anxious': 4.775869367784177,
#   'artistic': 2.6769446563375228,
#   'stressed': 10.091760482463654,
#   'health_oriented': 0.9029346,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto10',
#   'party': 'democrats',
#   'imaginative': -2.0310496808246654,
#   'netspeak_focus': 0.21141648999999998,
#   'persuasive': 2.443030253174941,
#   'liberal': 0.025413330400421152,
#   'self_assured': 1.0348614993061371,
#   'body_focus': 0.21141648999999998,
#   'trusting': -0.5513843254784572,
#   'organized': 1.235539821808603,
#   'type_a': 13.329002311881409,
#   'intellectual': 8.61233892869117,
#   'cheerful': -0.8300856845388966,
#   'disciplined': 4.110332562031044,
#   'neuroticism': 1.7364516580420915,
#   'cooperative': 3.73172836376893,
#   'social_skills': 1.4778790690586951,
#   'openness': -0.23151563619939464,
#   'aggressive': 6.816882085189509,
#   'adjustment': 3.4432217468722053,
#   'religion_oriented': 0.0,
#   'empathetic': -3.2138006143057503,
#   'food_focus': 0.42283297999999997,
#   'generous': -3.8938693260146686,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.5088881690904046,
#   'friend_focus': 0.0,
#   'extraversion': 0.44893221710364595,
#   'agreeableness': -6.787488197160868,
#   'depression': 1.8454233325189207,
#   'ambitious': 5.46053893236231,
#   'friendly': 1.3266276224943683,
#   'money_oriented': 1.0570823999999999,
#   'independent': -1.261800013265928,
#   'melancholy': 0.9738345294470439,
#   'workhorse': 1.3400800005215514,
#   'reward_bias': -1.0570824,
#   'energetic': -0.6174138865122614,
#   'happiness': 3.513097191458675,
#   'self_conscious': 3.8639773548387097,
#   'assertive': 2.4367332818175904,
#   'insecure': 0.5777125280698876,
#   'leisure_oriented': 0.6342495,
#   'impulsive': -1.2201052387064109,
#   'cautious': 6.575297832348932,
#   'conscientiousness': 2.4164236389893854,
#   'active': -0.6815286026183994,
#   'power_driven': 8.30879298887362,
#   'dutiful': 2.6296399367993217,
#   'genuine': -1.6087386297551276,
#   'adventurous': 0.27914745385131123,
#   'sociable': 2.5569779309389578,
#   'family_oriented': 5.356960242210105,
#   'cold': -2.8759448467058055,
#   'emotionally_aware': -2.832618231543694,
#   'humble': -2.170881148722245,
#   'anxious': 4.508382923137014,
#   'artistic': 2.8074838351997307,
#   'stressed': 11.937952448547044,
#   'health_oriented': 0.6342495,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto11',
#   'party': 'democrats',
#   'imaginative': -1.6805804793021002,
#   'netspeak_focus': 0.22123894,
#   'persuasive': 2.995576522724903,
#   'liberal': -1.3791183038672288,
#   'self_assured': 0.46956999677096656,
#   'body_focus': 0.22123894,
#   'trusting': 0.14202784301259097,
#   'organized': 1.6655785982954752,
#   'type_a': 10.553784042331651,
#   'intellectual': 7.968771741606399,
#   'cheerful': -0.23063670646217438,
#   'disciplined': 4.551556597125384,
#   'neuroticism': 1.7291029593525644,
#   'cooperative': 4.088665556085386,
#   'social_skills': 0.9930278966274537,
#   'openness': 0.03206579342941823,
#   'aggressive': 2.591115192127233,
#   'adjustment': 4.028443252080528,
#   'religion_oriented': 0.44247786999999994,
#   'empathetic': -2.8292783119572675,
#   'food_focus': 0.22123894,
#   'generous': -3.741634441203368,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.5753610836443417,
#   'friend_focus': 0.0,
#   'extraversion': 0.16903307106240004,
#   'agreeableness': -6.124077083398533,
#   'depression': 2.657313719910082,
#   'ambitious': 5.3411753114723215,
#   'friendly': 1.1814983722172148,
#   'money_oriented': 1.3274336,
#   'independent': -2.5202222861496404,
#   'melancholy': 3.754829583601816,
#   'workhorse': 0.8350726144985545,
#   'reward_bias': 0.4424779000000001,
#   'energetic': -2.4706818222974682,
#   'happiness': 3.373137532830425,
#   'self_conscious': 2.3993595250989785,
#   'assertive': 2.718917881398043,
#   'insecure': -1.5419760559769349,
#   'leisure_oriented': 0.44247786999999994,
#   'impulsive': -0.443572072903446,
#   'cautious': 6.090614507042254,
#   'conscientiousness': 2.408432561555112,
#   'active': -2.2909963327416056,
#   'power_driven': 9.033657671412563,
#   'dutiful': 2.605981868293359,
#   'genuine': -1.092417626690461,
#   'adventurous': 1.4725139357770427,
#   'sociable': 4.342314431999319,
#   'family_oriented': 2.0771170438551523,
#   'cold': -3.5179495935216485,
#   'emotionally_aware': -1.6091723993548896,
#   'humble': -3.0008376979958538,
#   'anxious': 4.8061677136121235,
#   'artistic': 2.6711721852423698,
#   'stressed': 11.001278409644284,
#   'health_oriented': 0.88495575,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto12',
#   'party': 'democrats',
#   'imaginative': -1.5859337062904295,
#   'netspeak_focus': 0.0,
#   'persuasive': 1.920848887598935,
#   'liberal': -0.8382101694099049,
#   'self_assured': 1.448949805876743,
#   'body_focus': 0.0,
#   'trusting': 0.8882427016853365,
#   'organized': 2.92150146076945,
#   'type_a': 10.70392900031186,
#   'intellectual': 8.316845396130123,
#   'cheerful': -0.14754077907894114,
#   'disciplined': 4.766028328073562,
#   'neuroticism': 1.556839823519362,
#   'cooperative': 4.877809999458471,
#   'social_skills': 2.2164573454226892,
#   'openness': 0.18314598357013187,
#   'aggressive': 2.4892646276797423,
#   'adjustment': 4.133164095799564,
#   'religion_oriented': 0.21459227,
#   'empathetic': -3.2373787868162696,
#   'food_focus': 0.42918454999999994,
#   'generous': -3.777408276339794,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.2186440203475577,
#   'friend_focus': 0.8583690999999999,
#   'extraversion': 0.7573573614302939,
#   'agreeableness': -6.734324107769802,
#   'depression': 1.1269757094932498,
#   'ambitious': 6.433904627272295,
#   'friendly': 2.052097716982534,
#   'money_oriented': 2.5,
#   'independent': -1.3922659370143737,
#   'melancholy': 2.0268293775142237,
#   'workhorse': 1.6832473612100827,
#   'reward_bias': -0.4291847,
#   'energetic': -0.8792272162098755,
#   'happiness': 5.610170185691336,
#   'self_conscious': 2.1179172892125715,
#   'assertive': 3.33845711667218,
#   'insecure': -1.666526096722293,
#   'leisure_oriented': 0.6437768,
#   'impulsive': 0.042297569069995156,
#   'cautious': 5.75560661971831,
#   'conscientiousness': 2.9682564939106726,
#   'active': -1.5749482859082498,
#   'power_driven': 10.164761824454787,
#   'dutiful': 3.119435146727897,
#   'genuine': -1.5720402935717297,
#   'adventurous': 1.3951538547945204,
#   'sociable': 4.698865076179837,
#   'family_oriented': 2.6093394292176786,
#   'cold': -3.448872337382303,
#   'emotionally_aware': -1.5201369619405172,
#   'humble': -3.8332747102187588,
#   'anxious': 5.377009931657705,
#   'artistic': 2.8981610807719926,
#   'stressed': 11.154391579039956,
#   'health_oriented': 1.0729614,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto13',
#   'party': 'democrats',
#   'imaginative': -0.7604926517016831,
#   'netspeak_focus': 0.20242914999999997,
#   'persuasive': 2.4364489144261765,
#   'liberal': -1.1081663263435193,
#   'self_assured': -1.0673490355733068,
#   'body_focus': 0.60728746,
#   'trusting': -1.6154802950734033,
#   'organized': 2.0663959328077177,
#   'type_a': 12.829512385845813,
#   'intellectual': 7.259112763142878,
#   'cheerful': -2.0814450099837796,
#   'disciplined': 2.736396431817622,
#   'neuroticism': 1.9822666387312853,
#   'cooperative': 3.0515209007477413,
#   'social_skills': -0.33153907981527836,
#   'openness': 0.5907089164072353,
#   'aggressive': 5.796703670281168,
#   'adjustment': 2.490551815361045,
#   'religion_oriented': 0.0,
#   'empathetic': -2.9484546875951176,
#   'food_focus': 0.20242914999999997,
#   'generous': -3.83739229085407,
#   'sexual_focus': 0.0,
#   'thinking_style': 1.9506225664913321,
#   'friend_focus': 0.0,
#   'extraversion': -0.4804152068168975,
#   'agreeableness': -5.7923268307748375,
#   'depression': 3.6537764293792643,
#   'ambitious': 1.8777723314930652,
#   'friendly': 0.192645074447387,
#   'money_oriented': 0.0,
#   'independent': -2.6774039025651843,
#   'melancholy': 4.311229186104553,
#   'workhorse': 1.1126567123625561,
#   'reward_bias': -0.20242910000000014,
#   'energetic': -1.6323948124227774,
#   'happiness': 0.7969823150360513,
#   'self_conscious': 2.621700893787575,
#   'assertive': 1.1825150414076124,
#   'insecure': 2.359072531295522,
#   'leisure_oriented': 1.0121457,
#   'impulsive': -0.8165240060468206,
#   'cautious': 4.877225936469883,
#   'conscientiousness': 1.5302542345545807,
#   'active': -2.290878445454646,
#   'power_driven': 5.342651499395753,
#   'dutiful': 1.7385211469397455,
#   'genuine': -0.26362249050480413,
#   'adventurous': 1.547550210958904,
#   'sociable': 2.6447221119161597,
#   'family_oriented': 7.038493352521233,
#   'cold': -3.439269434768428,
#   'emotionally_aware': -2.2521845184908553,
#   'humble': -2.509166724199054,
#   'anxious': 4.365793832272066,
#   'artistic': 4.465606940754039,
#   'stressed': 11.176147244935143,
#   'health_oriented': 0.60728746,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto14',
#   'party': 'democrats',
#   'imaginative': -1.5449748834903207,
#   'netspeak_focus': 0.21141648999999998,
#   'persuasive': 1.6143523315888466,
#   'liberal': -0.9340922065226556,
#   'self_assured': 0.24996632182208645,
#   'body_focus': 0.0,
#   'trusting': -0.8047155988989365,
#   'organized': 1.3488099774759104,
#   'type_a': 14.906764677656271,
#   'intellectual': 7.347133369553241,
#   'cheerful': -1.3947492493686877,
#   'disciplined': 3.723072297315422,
#   'neuroticism': 2.222938316084607,
#   'cooperative': 2.2790371441563675,
#   'social_skills': 0.5508460093516306,
#   'openness': -0.1460094798748094,
#   'aggressive': 6.88272503492496,
#   'adjustment': 3.604623305890654,
#   'religion_oriented': 0.21141648999999998,
#   'empathetic': -3.2116403927068724,
#   'food_focus': 0.0,
#   'generous': -3.9407616179502067,
#   'sexual_focus': 0.0,
#   'thinking_style': 1.9483351851003061,
#   'friend_focus': 0.0,
#   'extraversion': 0.2854642237226981,
#   'agreeableness': -7.621125465586048,
#   'depression': 2.244951187042793,
#   'ambitious': 3.737619278202086,
#   'friendly': 0.7776677184171332,
#   'money_oriented': 1.6913319,
#   'independent': -2.5751489580771105,
#   'melancholy': 2.3822819560774793,
#   'workhorse': 0.1567879428985668,
#   'reward_bias': -0.6342495,
#   'energetic': -1.2516633465122615,
#   'happiness': 1.491856946828931,
#   'self_conscious': 3.881465388906846,
#   'assertive': 2.929253177374662,
#   'insecure': 0.9594550603214718,
#   'leisure_oriented': 0.42283297999999997,
#   'impulsive': -0.7824443906295506,
#   'cautious': 6.128643254884143,
#   'conscientiousness': 2.101291898132685,
#   'active': -0.8870099241971919,
#   'power_driven': 7.5824650073465705,
#   'dutiful': 2.570099811258841,
#   'genuine': -2.3212926597542243,
#   'adventurous': 0.2919054176444147,
#   'sociable': 2.6927394112460377,
#   'family_oriented': 6.264641883315669,
#   'cold': -2.833658934007393,
#   'emotionally_aware': -2.589912698429473,
#   'humble': -2.726650033855031,
#   'anxious': 6.244076410322944,
#   'artistic': 3.2233471417055655,
#   'stressed': 14.674132941517524,
#   'health_oriented': 1.268499,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto15',
#   'party': 'democrats',
#   'imaginative': -1.3849640433935715,
#   'netspeak_focus': 0.0,
#   'persuasive': 3.0395148488876425,
#   'liberal': 0.7189318588338602,
#   'self_assured': 1.2628281041712637,
#   'body_focus': 0.0,
#   'trusting': 0.3908480084507153,
#   'organized': 2.8328832696837853,
#   'type_a': 10.027223907376225,
#   'intellectual': 7.8848912675919145,
#   'cheerful': 0.008613732389886941,
#   'disciplined': 4.1361890177809215,
#   'neuroticism': 0.9942155377187681,
#   'cooperative': 4.287788479442781,
#   'social_skills': 2.495641477945521,
#   'openness': 0.2932375721720897,
#   'aggressive': 2.435398339742569,
#   'adjustment': 5.0786495318279865,
#   'religion_oriented': 0.0,
#   'empathetic': -2.5123706217063053,
#   'food_focus': 0.22075055,
#   'generous': -3.6403266057180526,
#   'sexual_focus': 0.22075055,
#   'thinking_style': 2.780184196357973,
#   'friend_focus': 0.0,
#   'extraversion': 1.1062078065742684,
#   'agreeableness': -6.5589294933064295,
#   'depression': 0.5482162963183255,
#   'ambitious': 7.120600225625294,
#   'friendly': 2.059572894335979,
#   'money_oriented': 1.7660044,
#   'independent': 0.3941927089539259,
#   'melancholy': -1.2033272292234334,
#   'workhorse': -0.2974153621379094,
#   'reward_bias': 0.0,
#   'energetic': 0.7421320580695872,
#   'happiness': 4.454814118702525,
#   'self_conscious': 2.893349786935003,
#   'assertive': 2.9579089305241837,
#   'insecure': -1.2406744850503695,
#   'leisure_oriented': 0.66225166,
#   'impulsive': -0.2425657536761303,
#   'cautious': 6.023014815992731,
#   'conscientiousness': 2.8622442564311923,
#   'active': 0.11995932082686636,
#   'power_driven': 7.937808280847104,
#   'dutiful': 2.7086106025543883,
#   'genuine': -2.083939882797205,
#   'adventurous': 0.8962678760460632,
#   'sociable': 3.02893785363498,
#   'family_oriented': 3.2129462777746274,
#   'cold': -3.317396425746374,
#   'emotionally_aware': -0.3006871497681509,
#   'humble': -2.565026122168297,
#   'anxious': 4.428716233437452,
#   'artistic': 1.5595213855475762,
#   'stressed': 8.82994495352255,
#   'health_oriented': 0.8830022,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto16',
#   'party': 'democrats',
#   'imaginative': -1.953663060176627,
#   'netspeak_focus': 0.19417476,
#   'persuasive': 0.4375370244715163,
#   'liberal': 1.49521222597471,
#   'self_assured': 0.8422118264471807,
#   'body_focus': 0.0,
#   'trusting': -1.6241642112637524,
#   'organized': 2.1347387526358634,
#   'type_a': 13.548432079999051,
#   'intellectual': 8.555606178579358,
#   'cheerful': -0.648657422614159,
#   'disciplined': 3.5027888296704033,
#   'neuroticism': 2.381817432066094,
#   'cooperative': 2.748005836900143,
#   'social_skills': 0.7362042409214002,
#   'openness': 0.35276191573393834,
#   'aggressive': 4.916110948485074,
#   'adjustment': 2.102149551040838,
#   'religion_oriented': 0.38834952,
#   'empathetic': -2.9925545040732895,
#   'food_focus': 0.0,
#   'generous': -3.609864390986516,
#   'sexual_focus': 0.19417476,
#   'thinking_style': 1.455623954376267,
#   'friend_focus': 0.0,
#   'extraversion': 0.536188627092929,
#   'agreeableness': -7.723646525826393,
#   'depression': 3.218713768968664,
#   'ambitious': 5.409053481000067,
#   'friendly': 0.7700121016892754,
#   'money_oriented': 1.5533981000000001,
#   'independent': -3.1914294214018906,
#   'melancholy': 3.338213713096067,
#   'workhorse': 0.23419499294884183,
#   'reward_bias': -0.5825243000000001,
#   'energetic': 0.09296472820828083,
#   'happiness': 1.953337773364992,
#   'self_conscious': 5.068029442456904,
#   'assertive': 3.26120536642043,
#   'insecure': 1.3381255429180066,
#   'leisure_oriented': 0.19417476,
#   'impulsive': -0.03470487818208223,
#   'cautious': 6.526225964561563,
#   'conscientiousness': 2.3960502840800557,
#   'active': -2.5818551129162,
#   'power_driven': 8.359380431652662,
#   'dutiful': 2.1059093272836185,
#   'genuine': -2.796880352557152,
#   'adventurous': 0.5890076987322291,
#   'sociable': 5.278579401340897,
#   'family_oriented': 2.5581953049073154,
#   'cold': -1.212960657969124,
#   'emotionally_aware': -1.7172858617014541,
#   'humble': -3.000505574206731,
#   'anxious': 6.021088232015714,
#   'artistic': 4.2075918537701975,
#   'stressed': 14.343835574042558,
#   'health_oriented': 1.1650485,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto17',
#   'party': 'democrats',
#   'imaginative': -1.9283489271268197,
#   'netspeak_focus': 0.47732699999999995,
#   'persuasive': 2.1817082411721915,
#   'liberal': 0.13731331506849287,
#   'self_assured': 0.9298093837253778,
#   'body_focus': 0.0,
#   'trusting': -0.9994246720233058,
#   'organized': 2.504503536589459,
#   'type_a': 10.653707241319918,
#   'intellectual': 8.890844787495649,
#   'cheerful': -0.6201139402276441,
#   'disciplined': 3.904340219213635,
#   'neuroticism': 1.3152834740893733,
#   'cooperative': 5.301534108135545,
#   'social_skills': 1.380842872873364,
#   'openness': 0.36894244120837616,
#   'aggressive': 1.7360391763621896,
#   'adjustment': 3.8583279429544404,
#   'religion_oriented': 0.23866349999999997,
#   'empathetic': -1.7519983228790545,
#   'food_focus': 0.47732699999999995,
#   'generous': -2.354026936434499,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.57731161317719,
#   'friend_focus': 0.0,
#   'extraversion': 0.3764789695869615,
#   'agreeableness': -4.7453113092160555,
#   'depression': 1.7867346362957162,
#   'ambitious': 8.486563905369636,
#   'friendly': 1.5528252506806857,
#   'money_oriented': 1.1933174,
#   'independent': -1.4125041512078185,
#   'melancholy': -0.13535458497071517,
#   'workhorse': 2.8133926936709694,
#   'reward_bias': -0.9546539,
#   'energetic': -0.6317409258988504,
#   'happiness': 4.9880785389959525,
#   'self_conscious': 3.963845424677837,
#   'assertive': 2.5006897901449108,
#   'insecure': -0.6735612439320131,
#   'leisure_oriented': 0.47732699999999995,
#   'impulsive': 0.06280200301086358,
#   'cautious': 5.93795514538846,
#   'conscientiousness': 2.89801811259661,
#   'active': -2.0620852938292966,
#   'power_driven': 7.803614947756579,
#   'dutiful': 3.049940859461101,
#   'genuine': -1.8716907846525705,
#   'adventurous': 1.4609223527290598,
#   'sociable': 4.004171190117658,
#   'family_oriented': 2.7656457085168995,
#   'cold': -3.423528148856471,
#   'emotionally_aware': -0.47632435813172025,
#   'humble': -1.6247624918910701,
#   'anxious': 5.267370811559093,
#   'artistic': 3.2465947195691203,
#   'stressed': 9.501993785729793,
#   'health_oriented': 0.71599046,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto18',
#   'party': 'democrats',
#   'imaginative': -1.2372184375502284,
#   'netspeak_focus': 0.0,
#   'persuasive': 2.536875106461247,
#   'liberal': -1.395049468598525,
#   'self_assured': -0.30154022445949824,
#   'body_focus': 0.23364485,
#   'trusting': -0.959663522564751,
#   'organized': 0.817044972712248,
#   'type_a': 9.487298626265835,
#   'intellectual': 7.3718556565659945,
#   'cheerful': -0.143733984573031,
#   'disciplined': 2.4769540011982802,
#   'neuroticism': 1.6979442294115499,
#   'cooperative': 4.252121469434138,
#   'social_skills': 0.7882311514885894,
#   'openness': 0.6177277555976721,
#   'aggressive': 2.6028520286407986,
#   'adjustment': 3.5142080583529554,
#   'religion_oriented': 0.23364485,
#   'empathetic': -1.4332718895288115,
#   'food_focus': 0.0,
#   'generous': -2.0914633260836744,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.2315565125648034,
#   'friend_focus': 0.23364485,
#   'extraversion': 0.15446249801152936,
#   'agreeableness': -3.7190947110030077,
#   'depression': 1.9193609017270683,
#   'ambitious': 2.7171487875889095,
#   'friendly': 0.679416572464403,
#   'money_oriented': 0.9345794,
#   'independent': -2.5777004132000774,
#   'melancholy': 3.4466645849273725,
#   'workhorse': 0.1953218322991052,
#   'reward_bias': 0.4672897400000001,
#   'energetic': -1.2088396321521642,
#   'happiness': 3.0868759127482726,
#   'self_conscious': 2.3934352195121953,
#   'assertive': 2.270134872670033,
#   'insecure': -0.12163673154323551,
#   'leisure_oriented': 1.1682243,
#   'impulsive': 0.047288887572042304,
#   'cautious': 3.8053934243332335,
#   'conscientiousness': 1.3549001853036267,
#   'active': -1.7608186881882795,
#   'power_driven': 5.845802051278634,
#   'dutiful': 1.9304495423108974,
#   'genuine': -0.995511719319448,
#   'adventurous': 2.2342496559990557,
#   'sociable': 2.5580614767223238,
#   'family_oriented': 4.889185607092641,
#   'cold': -4.033454547765654,
#   'emotionally_aware': -0.2258730020044234,
#   'humble': -1.7128209539099548,
#   'anxious': 4.6693355408828365,
#   'artistic': 3.7932473445242367,
#   'stressed': 10.390912357725021,
#   'health_oriented': 0.9345794,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto19',
#   'party': 'democrats',
#   'imaginative': -0.9313916096625141,
#   'netspeak_focus': 0.6048387,
#   'persuasive': 1.392041287292695,
#   'liberal': 0.013894041833509174,
#   'self_assured': 0.4540895697662446,
#   'body_focus': 0.0,
#   'trusting': -0.34961649608974943,
#   'organized': 2.6776854936519063,
#   'type_a': 13.059749280235373,
#   'intellectual': 7.364477663658247,
#   'cheerful': -1.6098057503674146,
#   'disciplined': 2.362481892465788,
#   'neuroticism': 1.6458834900449357,
#   'cooperative': 1.6856485818087208,
#   'social_skills': 1.8276850996867364,
#   'openness': 0.3699051917627996,
#   'aggressive': 6.137396080597264,
#   'adjustment': 3.1809952772050756,
#   'religion_oriented': 0.4032258,
#   'empathetic': -3.151528849034645,
#   'food_focus': 0.0,
#   'generous': -3.753475498023707,
#   'sexual_focus': 0.0,
#   'thinking_style': 1.5440313418859406,
#   'friend_focus': 0.0,
#   'extraversion': 0.10596352888399815,
#   'agreeableness': -7.212481662906568,
#   'depression': 3.348984120456534,
#   'ambitious': 5.094921666910935,
#   'friendly': 1.140206376640542,
#   'money_oriented': 1.814516,
#   'independent': -3.2743320975208032,
#   'melancholy': 0.8162828530026209,
#   'workhorse': -0.1825084624410116,
#   'reward_bias': -0.8064515999999999,
#   'energetic': -0.6732328120220472,
#   'happiness': 3.034316470842565,
#   'self_conscious': 3.3309493488251087,
#   'assertive': 3.472572308987909,
#   'insecure': 0.4624358405651998,
#   'leisure_oriented': 1.6129032,
#   'impulsive': -0.5034156570073192,
#   'cautious': 5.08198127925411,
#   'conscientiousness': 2.064408260582472,
#   'active': -2.5033574548850464,
#   'power_driven': 6.53301664500456,
#   'dutiful': 1.5814291767919675,
#   'genuine': -2.206417931688805,
#   'adventurous': 0.5792173614350802,
#   'sociable': 2.4140795441081604,
#   'family_oriented': 5.221300769851576,
#   'cold': -2.604149461740695,
#   'emotionally_aware': -2.118370412786916,
#   'humble': -2.3546358809821433,
#   'anxious': 5.066588402973142,
#   'artistic': 3.512842368940754,
#   'stressed': 10.36511994526864,
#   'health_oriented': 0.2016129,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto20',
#   'party': 'democrats',
#   'imaginative': -1.4359730586186754,
#   'netspeak_focus': 0.0,
#   'persuasive': 1.7721210849789593,
#   'liberal': -0.23463976111111107,
#   'self_assured': 0.28771394802384087,
#   'body_focus': 0.0,
#   'trusting': -0.30148075540270325,
#   'organized': 0.6341522789978379,
#   'type_a': 14.71312729674604,
#   'intellectual': 8.92751081040175,
#   'cheerful': -1.7519397407900943,
#   'disciplined': 2.5399510386296633,
#   'neuroticism': 1.8518762748526911,
#   'cooperative': 2.2853005887355113,
#   'social_skills': 0.6821197753757285,
#   'openness': 0.14468466114829648,
#   'aggressive': 6.594016485944956,
#   'adjustment': 2.7091542993535485,
#   'religion_oriented': 0.1980198,
#   'empathetic': -3.59702412342216,
#   'food_focus': 0.1980198,
#   'generous': -4.1416972858957415,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.0001820992163037,
#   'friend_focus': 0.3960396,
#   'extraversion': -0.04330294560447365,
#   'agreeableness': -7.309133367307595,
#   'depression': 3.5625369251979038,
#   'ambitious': 6.392548803941583,
#   'friendly': 1.2703929096029194,
#   'money_oriented': 0.59405942,
#   'independent': -4.110724066569464,
#   'melancholy': 0.8008555462955202,
#   'workhorse': 1.2860034265593792,
#   'reward_bias': -1.1881188,
#   'energetic': -1.72100192455639,
#   'happiness': 5.16427548119486,
#   'self_conscious': 3.9362804033874204,
#   'assertive': 1.8560346432060226,
#   'insecure': 1.5490266498254004,
#   'leisure_oriented': 2.5,
#   'impulsive': 0.03623556221475843,
#   'cautious': 6.1965758019082235,
#   'conscientiousness': 1.8233056720623102,
#   'active': -1.5643353936155984,
#   'power_driven': 9.124446105632241,
#   'dutiful': 1.3652838407855747,
#   'genuine': -1.4803324028869613,
#   'adventurous': 0.6696116464404893,
#   'sociable': 3.0861818795825506,
#   'family_oriented': 7.1633855380433245,
#   'cold': -2.884464265873016,
#   'emotionally_aware': -1.5288515468246333,
#   'humble': -3.09214052558251,
#   'anxious': 6.263299384421677,
#   'artistic': 2.422098532136445,
#   'stressed': 10.08318016940791,
#   'health_oriented': 0.59405942,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto21',
#   'party': 'democrats',
#   'imaginative': -1.3116678934949852,
#   'netspeak_focus': 0.0,
#   'persuasive': 1.4100825322130877,
#   'liberal': -0.5485650335616439,
#   'self_assured': 1.2132131513673743,
#   'body_focus': 1.3574661,
#   'trusting': -0.9520348129592955,
#   'organized': 3.014390907947741,
#   'type_a': 12.782041219388864,
#   'intellectual': 8.084036928430255,
#   'cheerful': -1.0164753814147858,
#   'disciplined': 1.9454211702715796,
#   'neuroticism': 2.8794807647901557,
#   'cooperative': 2.1773846946875635,
#   'social_skills': 0.9931340937423997,
#   'openness': 0.057114690994648304,
#   'aggressive': 5.238122502581394,
#   'adjustment': 3.345992917902988,
#   'religion_oriented': 0.22624435,
#   'empathetic': -3.0234551627823696,
#   'food_focus': 0.0,
#   'generous': -3.595097125174691,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.3958599499312396,
#   'friend_focus': 0.9049774,
#   'extraversion': 0.5852980920289872,
#   'agreeableness': -7.624201598867258,
#   'depression': 2.2868071998019177,
#   'ambitious': 5.077960524539972,
#   'friendly': 0.50805051304798,
#   'money_oriented': 1.5837105,
#   'independent': -2.7254384939192806,
#   'melancholy': 3.845193309900717,
#   'workhorse': 2.217424454219013,
#   'reward_bias': 0.45248866,
#   'energetic': -0.7186784957471555,
#   'happiness': 3.9565630232661038,
#   'self_conscious': 5.5553005807744515,
#   'assertive': 3.6816728559005933,
#   'insecure': 2.272069525055408,
#   'leisure_oriented': 1.1312217,
#   'impulsive': 1.1544170546371968,
#   'cautious': 4.6665206839541025,
#   'conscientiousness': 2.1013651472832144,
#   'active': -1.1692296579849326,
#   'power_driven': 9.175292290774046,
#   'dutiful': 1.3464709239612516,
#   'genuine': -2.7470484286693173,
#   'adventurous': -0.21869021866305016,
#   'sociable': 4.106251656653395,
#   'family_oriented': 4.706032132028723,
#   'cold': -2.8721618924601526,
#   'emotionally_aware': -1.3405973791233803,
#   'humble': -3.020074626586521,
#   'anxious': 10.445092083978167,
#   'artistic': 3.2138984106822264,
#   'stressed': 13.45462968892766,
#   'health_oriented': 0.67873304,
#   'work_oriented': 2.5},
#  {'userid': 'RepDarrenSoto22',
#   'party': 'democrats',
#   'imaginative': -0.841989818153986,
#   'netspeak_focus': 0.4576659,
#   'persuasive': 0.9634935778739397,
#   'liberal': 1.9930762939819695,
#   'self_assured': 0.12213867241861198,
#   'body_focus': 0.0,
#   'trusting': -1.6722405936693738,
#   'organized': 2.250121657082265,
#   'type_a': 11.02818639764425,
#   'intellectual': 7.35110111164706,
#   'cheerful': -0.9874161702407331,
#   'disciplined': 2.5344619852292904,
#   'neuroticism': 1.674325527517373,
#   'cooperative': 1.789218798381706,
#   'social_skills': 1.085168413195342,
#   'openness': 0.7327774059269214,
#   'aggressive': 3.912276603230737,
#   'adjustment': 3.6541263443095877,
#   'religion_oriented': 0.22883294,
#   'empathetic': -2.5379828160902393,
#   'food_focus': 0.0,
#   'generous': -3.409304069489436,
#   'sexual_focus': 0.4576659,
#   'thinking_style': 2.5568809121537237,
#   'friend_focus': 0.22883294,
#   'extraversion': 0.6388880628448672,
#   'agreeableness': -7.361948865524304,
#   'depression': 1.845201846538314,
#   'ambitious': 6.294742372657049,
#   'friendly': 1.2704681448835022,
#   'money_oriented': 1.8306635000000002,
#   'independent': -1.8661912774799467,
#   'melancholy': -0.1921317892263663,
#   'workhorse': -1.289866198803532,
#   'reward_bias': -0.45766589999999985,
#   'energetic': 1.3959920914002795,
#   'happiness': 4.229416759408391,
#   'self_conscious': 4.501575479680053,
#   'assertive': 3.181894589710305,
#   'insecure': 0.15242841693870268,
#   'leisure_oriented': 2.0594966,
#   'impulsive': -0.1398512095746085,
#   'cautious': 6.7986415424806905,
#   'conscientiousness': 2.2523655944923897,
#   'active': -1.9432206917597057,
#   'power_driven': 7.671285908572078,
#   'dutiful': 1.7458318208494654,
#   'genuine': -2.935524479307852,
#   'adventurous': 0.38442593092058136,
# ...
#   'religion_oriented': 0.28089888,
#   'empathetic': -3.0196355930888363,
#   'food_focus': 0.28089888,
#   'generous': -3.9884634627592703,
#   'sexual_focus': 0.56179776,
#   'thinking_style': 0.2757419868369382,
#   'friend_focus': 0.0,
#   'extraversion': 0.7796650844402695,
#   'agreeableness': -7.101072869743526,
#   'depression': 1.1289097434296074,
#   'ambitious': 7.163142996913198,
#   'friendly': 1.7332202141455815,
#   'money_oriented': 2.5,
#   'independent': -2.5759117092009105,
#   'melancholy': 1.7518742074991118,
#   'workhorse': -2.4310683708576217,
#   'reward_bias': 1.6853932,
#   'energetic': 2.6465319109652734,
#   'happiness': 3.4263537494728986,
#   'self_conscious': 1.8694555364387309,
#   'assertive': 3.502886001084335,
#   'insecure': -1.9640690172416586,
#   'leisure_oriented': 0.0,
#   'impulsive': 1.2418335463618415,
#   'cautious': 4.575023542103686,
#   'conscientiousness': 2.4650841020974763,
#   'active': -3.045048446273735,
#   'power_driven': 10.824374650784975,
#   'dutiful': 1.2982604063079872,
#   'genuine': -1.567376569621397,
#   'adventurous': 2.0681627139230043,
#   'sociable': 4.281200638964174,
#   'family_oriented': 1.461925368006294,
#   'cold': -1.620100546640574,
#   'emotionally_aware': -0.9629783559106891,
#   'humble': -3.570818164495685,
#   'anxious': 3.1567007717323188,
#   'artistic': 3.2440163533572712,
#   'stressed': 11.452084487998901,
#   'health_oriented': 0.8426965999999999,
#   'work_oriented': 2.5},
#  {'userid': 'GOPLeader15',
#   'party': 'republicans',
#   'imaginative': -1.607355258933261,
#   'netspeak_focus': 0.0,
#   'persuasive': 1.1729408066544975,
#   'liberal': -1.4998347764594313,
#   'self_assured': 1.549474024015475,
#   'body_focus': 0.4819277,
#   'trusting': -1.7153547418671202,
#   'organized': 2.8303132495195387,
#   'type_a': 14.044743273880549,
#   'intellectual': 9.256012444147238,
#   'cheerful': -0.6160380495604598,
#   'disciplined': 4.104655703278042,
#   'neuroticism': 3.0243990328989105,
#   'cooperative': 1.3833528085434441,
#   'social_skills': 1.1716295432002384,
#   'openness': -0.006104337642015664,
#   'aggressive': 7.823556015548635,
#   'adjustment': 1.9852559888139916,
#   'religion_oriented': 0.24096386000000003,
#   'empathetic': -3.547669004207574,
#   'food_focus': 0.0,
#   'generous': -4.68282559891641,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.422070937763018,
#   'friend_focus': 0.24096386000000003,
#   'extraversion': -0.21148056302627594,
#   'agreeableness': -9.935145108765798,
#   'depression': 2.610078913893037,
#   'ambitious': 7.730082779337282,
#   'friendly': 0.9535755525215125,
#   'money_oriented': 2.5,
#   'independent': -1.3217209922605409,
#   'melancholy': 4.180183868022588,
#   'workhorse': 3.105538353538179,
#   'reward_bias': 1.6867469400000004,
#   'energetic': -2.137842379784845,
#   'happiness': 4.7192576113622895,
#   'self_conscious': 6.357712696098728,
#   'assertive': 4.046026972770154,
#   'insecure': 0.6333819818819832,
#   'leisure_oriented': 0.72289156,
#   'impulsive': 1.3235520067796815,
#   'cautious': 6.595892555936857,
#   'conscientiousness': 2.7928656057198733,
#   'active': -4.681577894722919,
#   'power_driven': 11.814162083692443,
#   'dutiful': 1.6587248550604818,
#   'genuine': -3.7481102250609926,
#   'adventurous': 0.26368896035777933,
#   'sociable': 3.492972022689727,
#   'family_oriented': 2.1429665323075437,
#   'cold': -1.7019711556069503,
#   'emotionally_aware': -0.7860586983047689,
#   'humble': -3.3760870148122746,
#   'anxious': 8.454669238866293,
#   'artistic': 2.99912393758079,
#   'stressed': 12.637635619301097,
#   'health_oriented': 0.9638554,
#   'work_oriented': 2.5},
#  {'userid': 'GOPLeader16',
#   'party': 'republicans',
#   'imaginative': -2.656753262193922,
#   'netspeak_focus': 0.0,
#   'persuasive': -0.3314100797033813,
#   'liberal': 1.2231351453108537,
#   'self_assured': 1.6596817251521347,
#   'body_focus': 0.0,
#   'trusting': -0.6016950804319308,
#   'organized': 1.5863859143568937,
#   'type_a': 14.336381407939323,
#   'intellectual': 9.498705292410586,
#   'cheerful': -1.7053892376208586,
#   'disciplined': 6.662187900158119,
#   'neuroticism': 1.7981231461169298,
#   'cooperative': 2.9384636820196106,
#   'social_skills': 1.0766564072626807,
#   'openness': 0.8259289698848391,
#   'aggressive': 6.5370380486859,
#   'adjustment': -0.4489317472882651,
#   'religion_oriented': 0.7025761,
#   'empathetic': -3.38684221598878,
#   'food_focus': 0.0,
#   'generous': -4.589030743722304,
#   'sexual_focus': 0.23419203,
#   'thinking_style': 1.1823400505763426,
#   'friend_focus': 0.0,
#   'extraversion': 0.012865697612076205,
#   'agreeableness': -7.473877392129334,
#   'depression': 3.9676292918653036,
#   'ambitious': 6.2303432322307,
#   'friendly': 0.6879801143259228,
#   'money_oriented': 2.5,
#   'independent': -3.463539620087708,
#   'melancholy': 4.150126015018161,
#   'workhorse': -1.542996515492637,
#   'reward_bias': 0.23419199999999996,
#   'energetic': -0.6278465655198329,
#   'happiness': 3.059606536153747,
#   'self_conscious': 1.8074648337650914,
#   'assertive': 3.7163585899968696,
#   'insecure': -1.9794590120775668,
#   'leisure_oriented': 0.0,
#   'impulsive': -1.695968335443181,
#   'cautious': 6.9790876056338025,
#   'conscientiousness': 2.7200669097966235,
#   'active': -3.3337168431372453,
#   'power_driven': 10.885910963157036,
#   'dutiful': 1.5947191054032264,
#   'genuine': -1.4155871140176501,
#   'adventurous': 3.1685867043575815,
#   'sociable': 3.2729178749285945,
#   'family_oriented': 2.0100657057552596,
#   'cold': -1.764171561933754,
#   'emotionally_aware': -0.21632093419798218,
#   'humble': -2.3216862208706077,
#   'anxious': 3.404522367884972,
#   'artistic': 4.788938074865349,
#   'stressed': 11.563484399804969,
#   'health_oriented': 2.1077282999999998,
#   'work_oriented': 2.5},
#  {'userid': 'GOPLeader17',
#   'party': 'republicans',
#   'imaginative': -1.428506594782389,
#   'netspeak_focus': 0.0,
#   'persuasive': 1.1322159449222582,
#   'liberal': -1.3631219079288137,
#   'self_assured': 0.627774669433534,
#   'body_focus': 0.8658009,
#   'trusting': 0.33716277206698564,
#   'organized': 1.8233344831048695,
#   'type_a': 14.476054672625676,
#   'intellectual': 8.701939004252303,
#   'cheerful': -1.4392687218790834,
#   'disciplined': 4.44817891753954,
#   'neuroticism': 1.3727915256135765,
#   'cooperative': 1.1103449494891537,
#   'social_skills': 0.7455357022770458,
#   'openness': 0.012736112705274416,
#   'aggressive': 6.819920256262075,
#   'adjustment': 1.222357584650824,
#   'religion_oriented': 0.0,
#   'empathetic': -3.3824261684819907,
#   'food_focus': 0.21645022,
#   'generous': -4.318498544159603,
#   'sexual_focus': 0.0,
#   'thinking_style': 1.6633637117716575,
#   'friend_focus': 0.21645022,
#   'extraversion': 0.7010017983922819,
#   'agreeableness': -7.1033402657552696,
#   'depression': 1.570780401868856,
#   'ambitious': 6.713242445564683,
#   'friendly': 1.2557701085361623,
#   'money_oriented': 2.5,
#   'independent': -0.8013452892369803,
#   'melancholy': 0.5833797204325,
#   'workhorse': -0.6284715192500984,
#   'reward_bias': 0.8658008700000002,
#   'energetic': 0.22245183445186634,
#   'happiness': 4.644890809524647,
#   'self_conscious': 1.4405328529253631,
#   'assertive': 3.500482066401779,
#   'insecure': -0.44408164004276296,
#   'leisure_oriented': 0.21645022,
#   'impulsive': 1.166064225457688,
#   'cautious': 3.06156730626311,
#   'conscientiousness': 1.9430672438537016,
#   'active': -0.9352502502962976,
#   'power_driven': 7.933200069008368,
#   'dutiful': 1.0333151997474175,
#   'genuine': -1.1136632783651095,
#   'adventurous': 1.0257357952527162,
#   'sociable': 3.6463995863060292,
#   'family_oriented': 5.0866385151029085,
#   'cold': -1.1810367790247551,
#   'emotionally_aware': -1.0155725543574845,
#   'humble': -3.207064576304199,
#   'anxious': 2.53324889745706,
#   'artistic': 1.704011133859964,
#   'stressed': 8.325021837886025,
#   'health_oriented': 1.7316017,
#   'work_oriented': 2.5},
#  {'userid': 'GOPLeader18',
#   'party': 'republicans',
#   'imaginative': -1.9946384457121402,
#   'netspeak_focus': 0.73891627,
#   'persuasive': 0.3131074893987393,
#   'liberal': -2.0821373603793467,
#   'self_assured': 1.6855289802960325,
#   'body_focus': 0.0,
#   'trusting': -0.7020343247417338,
#   'organized': 2.8098234404925617,
#   'type_a': 13.679217949778764,
#   'intellectual': 9.328468361141908,
#   'cheerful': -0.9300427562287541,
#   'disciplined': 4.561357973570998,
#   'neuroticism': 1.8157540179588212,
#   'cooperative': 2.3081097831491575,
#   'social_skills': 1.501193378600003,
#   'openness': -0.41784373347785403,
#   'aggressive': 5.221120470038061,
#   'adjustment': 2.434349936021023,
#   'religion_oriented': 0.0,
#   'empathetic': -3.5190756661991585,
#   'food_focus': 0.24630541,
#   'generous': -4.68146073610767,
#   'sexual_focus': 0.0,
#   'thinking_style': 1.928137419317113,
#   'friend_focus': 0.0,
#   'extraversion': -0.04342546259542872,
#   'agreeableness': -8.76775199060393,
#   'depression': 1.5298820442172727,
#   'ambitious': 9.422743348009806,
#   'friendly': 1.1235348374510787,
#   'money_oriented': 2.5,
#   'independent': -1.441711596656419,
#   'melancholy': 0.5974621920077956,
#   'workhorse': 1.586462471153792,
#   'reward_bias': 1.7241380000000004,
#   'energetic': -1.4889238467256498,
#   'happiness': 5.320480019768694,
#   'self_conscious': 4.118696803452696,
#   'assertive': 3.479938029613944,
#   'insecure': -1.4966444945312851,
#   'leisure_oriented': 0.73891627,
#   'impulsive': 1.3480759245035143,
#   'cautious': 5.507329917025143,
#   'conscientiousness': 3.0151430846112994,
#   'active': -3.82566656650033,
#   'power_driven': 11.112786495984068,
#   'dutiful': 2.3387647111979235,
#   'genuine': -2.2293498068619924,
#   'adventurous': 1.2353046876519573,
#   'sociable': 3.75093162615219,
#   'family_oriented': 4.367166904940124,
#   'cold': -4.0091921850731715,
#   'emotionally_aware': -2.011318424570148,
#   'humble': -4.58491027526115,
#   'anxious': 4.964053830446874,
#   'artistic': 1.0895808479533213,
#   'stressed': 10.421577682228756,
#   'health_oriented': 0.49261083,
#   'work_oriented': 2.5},
#  {'userid': 'GOPLeader19',
#   'party': 'republicans',
#   'imaginative': -1.6889724144760228,
#   'netspeak_focus': 0.23255814,
#   'persuasive': 0.7316841841019127,
#   'liberal': -0.389952160403934,
#   'self_assured': 2.130289063343729,
#   'body_focus': 0.0,
#   'trusting': 0.3001048257531771,
#   'organized': 3.2493208968538685,
#   'type_a': 9.21871195111647,
#   'intellectual': 8.75290494837086,
#   'cheerful': -0.7172454390177303,
#   'disciplined': 4.0929105234967,
#   'neuroticism': 0.9111948477095207,
#   'cooperative': 4.611726305075858,
#   'social_skills': 2.5509726001938997,
#   'openness': 0.19059568817914813,
#   'aggressive': 2.9647686682187837,
#   'adjustment': 2.1015633200133954,
#   'religion_oriented': 0.23255814,
#   'empathetic': -2.8936003971830146,
#   'food_focus': 0.0,
#   'generous': -4.365962014184879,
#   'sexual_focus': 0.0,
#   'thinking_style': 1.9568583585324981,
#   'friend_focus': 0.0,
#   'extraversion': 0.5545772565293672,
#   'agreeableness': -7.053054806307756,
#   'depression': -0.5538810510687112,
#   'ambitious': 7.294957715717682,
#   'friendly': 2.2730144078304027,
#   'money_oriented': 2.5,
#   'independent': -0.9112273188864274,
#   'melancholy': -0.9518876871816137,
#   'workhorse': 0.20663460857219162,
#   'reward_bias': 0.93023256,
#   'energetic': 1.1952024696422983,
#   'happiness': 4.1105132279836525,
#   'self_conscious': 1.7807594782736205,
#   'assertive': 3.2131416309092025,
#   'insecure': -1.8749235342159747,
#   'leisure_oriented': 0.4651163,
#   'impulsive': 2.1287476198121347,
#   'cautious': 1.3171557965238239,
#   'conscientiousness': 2.5026882617036112,
#   'active': -2.413969425333914,
#   'power_driven': 8.158358752299431,
#   'dutiful': 2.2209114564710344,
#   'genuine': -1.6411166952802627,
#   'adventurous': 1.4259428621634385,
#   'sociable': 2.322394357843616,
#   'family_oriented': 4.496713338794012,
#   'cold': -3.289524563141197,
#   'emotionally_aware': -0.3484775088107722,
#   'humble': -2.43679784523172,
#   'anxious': 2.413495813220515,
#   'artistic': 1.7264415478994612,
#   'stressed': 5.876036886787176,
#   'health_oriented': 0.4651163,
#   'work_oriented': 2.5},
#  {'userid': 'GOPLeader20',
#   'party': 'republicans',
#   'imaginative': -1.6774162410060072,
#   'netspeak_focus': 0.22271716000000003,
#   'persuasive': 1.7664551433740814,
#   'liberal': -1.0477621067439413,
#   'self_assured': 1.3899899518292949,
#   'body_focus': 0.22271716000000003,
#   'trusting': 0.5820886184965537,
#   'organized': 2.5839092360666247,
#   'type_a': 11.10437630095245,
#   'intellectual': 8.840980561880889,
#   'cheerful': 0.24455295226926577,
#   'disciplined': 4.082728826321873,
#   'neuroticism': 1.3564254342693236,
#   'cooperative': 4.721117885791232,
#   'social_skills': 2.2689839673685714,
#   'openness': 0.1623037578645649,
#   'aggressive': 2.756392334405552,
#   'adjustment': 2.7093663425808585,
#   'religion_oriented': 0.0,
#   'empathetic': -3.4324401647220317,
#   'food_focus': 0.0,
#   'generous': -4.526726462618183,
#   'sexual_focus': 0.0,
#   'thinking_style': 1.344243328706726,
#   'friend_focus': 0.44543430000000006,
#   'extraversion': 0.36601521998799785,
#   'agreeableness': -7.49148428369185,
#   'depression': 2.2126552566011783,
#   'ambitious': 8.801452730671269,
#   'friendly': 1.842091229870995,
#   'money_oriented': 2.5,
#   'independent': -1.7958699247239183,
#   'melancholy': 0.7777267771244301,
#   'workhorse': 0.4452564703135763,
#   'reward_bias': 0.8908686000000001,
#   'energetic': -1.3804641052465396,
#   'happiness': 7.066935486025274,
#   'self_conscious': 2.1787286577056557,
#   'assertive': 3.19332656445702,
#   'insecure': -1.6030252781639729,
#   'leisure_oriented': 0.8908686000000001,
#   'impulsive': 1.2604201219672677,
#   'cautious': 4.104616339526522,
#   'conscientiousness': 2.6831376737240724,
#   'active': -3.233349345558305,
#   'power_driven': 9.899872353341266,
#   'dutiful': 2.2908654894748346,
#   'genuine': -1.4574494005828138,
#   'adventurous': 1.901959283998583,
#   'sociable': 4.68998536196406,
#   'family_oriented': 3.003834692889549,
#   'cold': -3.6373444807995154,
#   'emotionally_aware': -1.5063698663962972,
#   'humble': -3.6974497240385347,
#   'anxious': 4.802072528179531,
#   'artistic': 2.2587597768402157,
#   'stressed': 8.304860657495563,
#   'health_oriented': 0.44543430000000006,
#   'work_oriented': 2.5},
#  {'userid': 'GOPLeader21',
#   'party': 'republicans',
#   'imaginative': -2.4527905832305885,
#   'netspeak_focus': 0.0,
#   'persuasive': 1.214737016624981,
#   'liberal': -1.6307893150684931,
#   'self_assured': 1.2814675819149612,
#   'body_focus': 0.0,
#   'trusting': -0.8759635114097106,
#   'organized': 2.9591243302227914,
#   'type_a': 12.067940934320841,
#   'intellectual': 8.603840904533843,
#   'cheerful': -0.8328464475524795,
#   'disciplined': 5.587226587276211,
#   'neuroticism': 1.4948923749881406,
#   'cooperative': 2.776239491969573,
#   'social_skills': 1.1156110723249375,
#   'openness': -0.4013791527477303,
#   'aggressive': 3.4977530990225336,
#   'adjustment': 2.657259004853167,
#   'religion_oriented': 0.23809525,
#   'empathetic': -3.7355573632538572,
#   'food_focus': 0.0,
#   'generous': -4.7360831776176235,
#   'sexual_focus': 0.0,
#   'thinking_style': 2.0079535521999596,
#   'friend_focus': 0.23809525,
#   'extraversion': -0.26051252016746324,
#   'agreeableness': -8.036154958810398,
#   'depression': 1.9759774449680325,
#   'ambitious': 9.561514380395128,
#   'friendly': 0.7072433520824764,
#   'money_oriented': 2.5,
#   'independent': -1.6033546247669501,
#   'melancholy': 2.450164609946804,
#   'workhorse': 1.862077311840178,
#   'reward_bias': 1.9047619,
#   'energetic': -2.5575387126295057,
#   'happiness': 6.479651846699692,
#   'self_conscious': 1.974448292682927,
#   'assertive': 3.6792908581429624,
#   'insecure': -2.4671940918741355,
#   'leisure_oriented': 0.23809525,
#   'impulsive': 1.0210477584267288,
#   'cautious': 3.2000515672759966,
#   'conscientiousness': 2.9461017710046113,
#   'active': -4.039539635378354,
#   'power_driven': 11.832239528033881,
#   'dutiful': 2.698827974089467,
#   'genuine': -1.3814145700807203,
#   'adventurous': 2.0371932478271138,
#   'sociable': 3.400358890880173,
#   'family_oriented': 2.6218074179472,
#   'cold': -4.042033269493698,
#   'emotionally_aware': -1.8983807059874072,
#   'humble': -3.6136700978525322,
#   'anxious': 4.334073181407776,
#   'artistic': 1.1203727377019748,
#   'stressed': 7.117059813516248,
#   'health_oriented': 0.7142857,
#   'work_oriented': 2.5}]

# %%
df_raw = pd.DataFrame(raw_scores)
df_percent = pd.DataFrame(percentile_scores)
df_cat = pd.DataFrame(category_scores)


df_raw.to_csv('liwc_raw_scores.csv',index=False)
df_percent.to_csv('liwc_percentile_scores.csv',index=False)
df_cat.to_csv('liwc_categorical_scores.csv',index=False)
