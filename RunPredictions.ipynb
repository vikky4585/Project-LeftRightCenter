# %%
import numpy as np
import pandas as pd
import PredictorNeuralNetworkFunction as pnn
df = pd.read_csv('liwc_categorical_scores.csv') 
y = df['party']
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#svm
X = df.drop(['party','userid'], axis=1)
pnn.runSVM(X,y, 'raw_full')
# Out:
# Test Acc: 0.438
#              precision    recall  f1-score   support
#
#   democrats       0.00      0.00      0.00        50
# republicans       0.44      1.00      0.61        39
#
# avg / total       0.19      0.44      0.27        89
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#Full run - raw
X = df.drop(['party','userid'], axis=1)
pnn.runPredictor(X,y, 'raw_full')
# Out:
# ***Running for raw_full X size: (353, 85), y size: (353,)
# Epoch 1/500
#  - 0s - loss: 0.6928 - acc: 0.5000
# Epoch 2/500
#  - 0s - loss: 0.6872 - acc: 0.5379
# Epoch 3/500
#  - 0s - loss: 0.6856 - acc: 0.5000
# Epoch 4/500
#  - 0s - loss: 0.6822 - acc: 0.6477
# Epoch 5/500
#  - 0s - loss: 0.6757 - acc: 0.7765
# Epoch 6/500
#  - 0s - loss: 0.6722 - acc: 0.6326
# Epoch 7/500
#  - 0s - loss: 0.6630 - acc: 0.7614
# Epoch 8/500
#  - 0s - loss: 0.6561 - acc: 0.6629
# Epoch 9/500
#  - 0s - loss: 0.6463 - acc: 0.6894
# Epoch 10/500
#  - 0s - loss: 0.6323 - acc: 0.7424
# Epoch 11/500
#  - 0s - loss: 0.6243 - acc: 0.7273
# Epoch 12/500
#  - 0s - loss: 0.6019 - acc: 0.7424
# Epoch 13/500
#  - 0s - loss: 0.5766 - acc: 0.7803
# Epoch 14/500
#  - 0s - loss: 0.5573 - acc: 0.7917
# Epoch 15/500
#  - 0s - loss: 0.5332 - acc: 0.7841
# Epoch 16/500
#  - 0s - loss: 0.5116 - acc: 0.7917
# Epoch 17/500
#  - 0s - loss: 0.5104 - acc: 0.7614
# Epoch 18/500
#  - 0s - loss: 0.4715 - acc: 0.7955
# ...

# %%
#Big5 - raw

X= df[['openness','conscientiousness','extraversion','agreeableness','neuroticism']]
pnn.runPredictor(X,y, 'raw_big5')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-1da0acfed924> in <module>()
#       1 #Big5 - raw
#       2
# ----> 3 X= df[['openness','conscientiousness','extraversion','agreeableness','neuroticism']]
#       4 pnn.runPredictor(X,y, 'raw_big5')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# ...

# %%
# aggressive - raw
X= df[['sad','anger','power']]
X= df[['differ']]


pnn.runPredictor(X,y, 'raw_aggressive')
# Out:
# ***Running for raw_aggressive X size: (353, 1), y size: (353,)
# Epoch 1/500
#  - 0s - loss: 0.6934 - acc: 0.5000
# Epoch 2/500
#  - 0s - loss: 0.6929 - acc: 0.5189
# Epoch 3/500
#  - 0s - loss: 0.6924 - acc: 0.5000
# Epoch 4/500
#  - 0s - loss: 0.6924 - acc: 0.5303
# Epoch 5/500
#  - 0s - loss: 0.6921 - acc: 0.5947
# Epoch 6/500
#  - 0s - loss: 0.6918 - acc: 0.5038
# Epoch 7/500
#  - 0s - loss: 0.6914 - acc: 0.5000
# Epoch 8/500
#  - 0s - loss: 0.6909 - acc: 0.5758
# Epoch 9/500
#  - 0s - loss: 0.6907 - acc: 0.5265
# Epoch 10/500
#  - 0s - loss: 0.6896 - acc: 0.5985
# Epoch 11/500
#  - 0s - loss: 0.6895 - acc: 0.5000
# Epoch 12/500
#  - 0s - loss: 0.6888 - acc: 0.5076
# Epoch 13/500
#  - 0s - loss: 0.6877 - acc: 0.5303
# Epoch 14/500
#  - 0s - loss: 0.6872 - acc: 0.5227
# Epoch 15/500
#  - 0s - loss: 0.6858 - acc: 0.5833
# Epoch 16/500
#  - 0s - loss: 0.6845 - acc: 0.6098
# Epoch 17/500
#  - 0s - loss: 0.6828 - acc: 0.6136
# Epoch 18/500
#  - 0s - loss: 0.6820 - acc: 0.6326
# ...
