# %%
import numpy as np
import pandas as pd
import PredictorNeuralNetworkFunction as pnn
#df = pd.read_csv('data/liwc_raw_scores_full.csv') 
#df = pd.read_csv('data/liwc_percentile_scores_full.csv') 

df = pd.read_csv('data/liwc_categorical_scores_full.csv') 

y = df['party']
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#svm
#X = df.drop(['party','userid'], axis=1)
#pnn.runSVM(X,y, 'raw_full')

# %%
#Full run - raw
X = df.drop(['party'], axis=1)
pnn.runPredictor(X,y, 'liwc_categorical_scores_full')
# Out:
# ***Running for liwc_categorical_scores_full X size: (3520, 85), y size: (3520,)
# Epoch 1/200
#  - 0s - loss: 0.6769 - acc: 0.5894
# Epoch 2/200
#  - 0s - loss: 0.6030 - acc: 0.7106
# Epoch 3/200
#  - 0s - loss: 0.5232 - acc: 0.7606
# Epoch 4/200
#  - 0s - loss: 0.4868 - acc: 0.7780
# Epoch 5/200
#  - 0s - loss: 0.4694 - acc: 0.7890
# Epoch 6/200
#  - 0s - loss: 0.4511 - acc: 0.7966
# Epoch 7/200
#  - 0s - loss: 0.4390 - acc: 0.8019
# Epoch 8/200
#  - 0s - loss: 0.4238 - acc: 0.8072
# Epoch 9/200
#  - 0s - loss: 0.4267 - acc: 0.8019
# Epoch 10/200
#  - 0s - loss: 0.4096 - acc: 0.8140
# Epoch 11/200
#  - 0s - loss: 0.4006 - acc: 0.8182
# Epoch 12/200
#  - 0s - loss: 0.3977 - acc: 0.8227
# Epoch 13/200
#  - 0s - loss: 0.4005 - acc: 0.8155
# Epoch 14/200
#  - 0s - loss: 0.3987 - acc: 0.8193
# Epoch 15/200
#  - 0s - loss: 0.3858 - acc: 0.8295
# Epoch 16/200
#  - 0s - loss: 0.3836 - acc: 0.8303
# Epoch 17/200
#  - 0s - loss: 0.3744 - acc: 0.8348
# Epoch 18/200
# ...

# %%
#Big5 - raw

X= df[['openness','conscientiousness','extraversion','agreeableness','neuroticism']]
pnn.runPredictor(X,y, 'liwc_raw_scores_full_big5')

# %%
X = df[['aggressive']]
pnn.runPredictor(X,y, 'liwc_raw_scores_full_aggressive')

# %%
# aggressive - raw
X= df[['sad','anger','power']]
X= df[['differ']]


pnn.runPredictor(X,y, 'raw_aggressive')

# %%
X= df[['cogproc','function','relativ','verb','social']]
pnn.runPredictor(X,y, 'liwc_categorical_scores_full_top5')
# Out:
# ***Running for liwc_categorical_scores_full_top5 X size: (3520, 5), y size: (3520,)
# Epoch 1/200
#  - 0s - loss: 0.6908 - acc: 0.5803
# Epoch 2/200
#  - 0s - loss: 0.6785 - acc: 0.6053
# Epoch 3/200
#  - 0s - loss: 0.6450 - acc: 0.6917
# Epoch 4/200
#  - 0s - loss: 0.6120 - acc: 0.6795
# Epoch 5/200
#  - 0s - loss: 0.5894 - acc: 0.7114
# Epoch 6/200
#  - 0s - loss: 0.5834 - acc: 0.7072
# Epoch 7/200
#  - 0s - loss: 0.5776 - acc: 0.7159
# Epoch 8/200
#  - 0s - loss: 0.5790 - acc: 0.7095
# Epoch 9/200
#  - 0s - loss: 0.5737 - acc: 0.7136
# Epoch 10/200
#  - 0s - loss: 0.5686 - acc: 0.7216
# Epoch 11/200
#  - 0s - loss: 0.5718 - acc: 0.7182
# Epoch 12/200
#  - 0s - loss: 0.5772 - acc: 0.7064
# Epoch 13/200
#  - 0s - loss: 0.5636 - acc: 0.7265
# Epoch 14/200
#  - 0s - loss: 0.5637 - acc: 0.7193
# Epoch 15/200
#  - 0s - loss: 0.5692 - acc: 0.7095
# Epoch 16/200
#  - 0s - loss: 0.5640 - acc: 0.7254
# Epoch 17/200
#  - 0s - loss: 0.5619 - acc: 0.7205
# Epoch 18/200
# ...
